# %% [markdown]
# # CHAPTER 6
# ## 6.1 Benchmark: Split Data into Training and Test Sets
# Now that we have a convenient way to make recommendations, we still need to make an informed choice as to which of `bestPy`'s algorithms we should pick and how we should set its parameters to achieve the highest possible fidelity in our recommendations.
#
# The only way of telling how well we are doing with our recommendations is to see how well we can predict _future_ purchases from _past_ purchases. This means that, instead of using _all_ of our data to _train_ an algorithm, we have to hold out the _last_ couple of purchases of each user and only used the rest. Then, we can _test_ the recommendations produced by our algorithm against what customers actually did buy next.
#
# To conveniently perform this split of our data into training and test sets, `bestPy` offers the advanced data class `TrainTest`.
#
#
# ### Preliminaries
# We only need this because the examples folder is a subdirectory of the `bestPy` package.

# %%
import sys
sys.path.append('../..')

# %% [markdown]
# ### Imports and logging
# No algorithm or recommender is needed for now as we are focusing solely on the data structure `TrainTest`, which is, naturally, accessible through the sub-package `bestPy.datastructures`.

# %%
from bestPy import write_log_to
from bestPy.datastructures import TrainTest  # Additionally import RecoBasedOn

logfile = 'logfile.txt'
write_log_to(logfile, 20)

# %% [markdown]
# ### Read `TrainTest` data
# Reading in `TrainTest` data works in pretty much the same way as reading in `Transactions` data. Again, two data sources are available, a postgreSQL database and a CSV file. For the former, we again need a fully configured `PostgreSQLparams` instance (let's call it `database`) before we can read in the data with:
#
# ```
# data = TrainTest.from_postgreSQL(database)
# ```
#
# Reading from then works like so:

# %%
file = 'examples_data.csv'
data = TrainTest.from_csv(file)

# %% [markdown]
# __NOTE__: There is only one difference to reading `Transactions` data. The `from_csv()` class method has an addtional argument `fmt`. If it is _not_ given, then the timestamps in the CSV file are assumed to be _UNIX timestamp since epoch_, i.e., integer numbers.
#
# If, on the other hand, it _is_ given, then it must be a valid _format string_ specifying the format in which the timestamps are written in the CSV file. To tell `bestPy` that, for example, the timestamps in your CSV file look like
# ```
# 2012-03-09 16:18:02
# ```
# _i.e._, year-month-day hour:minute:second, you would have to set `fmt` to the string:
# ```
# '%Y-%m-%d %H:%M:%S'
# ```
#
# With the [documentation](https://docs.python.org/3/library/datetime.html) of the `datetime` package, it should be easy to assemble the correct format string for just about any which way a timestamp could possible be composed.

# %% [markdown]
# ### Initial attributes of `TrainTest` data objects
# Inspecting the new `data` object with Tab completion reveals reveals several attribute that we already now from `Transactions` data. Notably, these are:

# %%
print(data.number_of_corrupted_records)
print(data.number_of_transactions)
# Out:
# 2
# 100000

# %% [markdown]
# There is also an additional attribute that tells us the maximum numbers of purchases we can possibly hold out as test data for each customer.

# %%
data.max_hold_out
# Out:
# 983

# %% [markdown]
# ### Splitting the data into training and test sets
# Also present is a method called `split()`, which indeed does exactly what you think it should. It has two arguments, `hold_out` and `only_new`. Naturally, the former tells `bestPy` how many unique purchases per cutomer to hold out (_i.e._, put aside) for each customer. Naturally, cutomers who bought fewer than `hold_out` articles cannot be tested at all and cutomers who bought exactly `hold_out` articles will be treated as _new_ customers in testing.
#
# The second argument, `only_new` tells `bestPy` whether only new articles will be recommended in the benchmark run or whether recommendations will include also articles that customers bouhgt before. If `True`, then all previous buys of any of the `hold_out` last unique items need to be deleted from the training data for each customer. Let's try.

# %%
data.split(4, False)

# %% [markdown]
# ### Attributes of split `TrainTest` data objects
# Inspecting the `TrainTest` data object with Tab completion again reveals two more attributes that magically appeared, `train` and `test`. The former is an instance of `Transactions` with all the attributes we already know.

# %%
print(type(data.train))
print(data.train.user.count)
# Out:
# <class 'bestPy.datastructures.transactions.transactions.Transactions'>
# 2141

# %% [markdown]
# So we have 2141 customers that bought 4 items or more and whose next 4 purchases can therefore be compared to our recommendations. I suggest you make it a habbit of checking that you have a decent number of customers left in your training set.
#
# __NOTE__: Should you, for some reason, chose to hold out `max_hold_out` purchases, you might well end up with a single customer in your training set and, therefore, obtain spurious benchmark results.
#
# The `test` attribute of a split `TrainTest` instance is a new, auxiliary data type with a very simple structure. Its `data` attribute contains the test data in the form of a `python` _dictionary_ with customer IDs as keys and the artcile IDs of their `hold_out` last unique purchases as values.

# %%
data.test.data
# Out:
# {'1': {'AP082EL37CPUALID-1762',
#   'CL225EL36CTRALID-1863',
#   'GR087ME45LMG-7753',
#   'NE739EL06ORLANID-27491'},
#  '12': {'AP082EL37CPUALID-1762',
#   'MA130HL15VTSANID-32883',
#   'NE739EL06ORLANID-27491',
#   'PH789EL86AANALID-13'},
#  '11': {'BL152EL82CRXALID-1817',
#   'CA189EL29AGOALID-170',
#   'LE629EL54ANHALID-345',
#   'SA848EL83DOYALID-2416'},
#  '10': {'CO142HB25OYKANID-27672',
#   'GR087ME41QJI-11057',
#   'GR087ME54QIV-11044',
#   'NE739EL06ORLANID-27491'},
#  '7': {'AC016EL58BKFALID-941',
#   'AP082EL03BMIALID-996',
#   'AS100EL41BOSALID-1058',
#   'OL756EL65HDYALID-4834'},
#  '13': {'AP082EL37CPUALID-1762',
#   'AS100EL41BOSALID-1058',
#   'BL152EL82CRXALID-1817',
#   'PI794EL32ENZALID-3067'},
#  '17': {'CA189EL29AGOALID-170',
#   'LA407HL45ZWGANID-35839',
#   'MA130HL30AQBANID-36435',
#   'MO717EL52ARFALID-447'},
#  '19': {'AC016EL58BKFALID-941',
#   'AD029EL42BKVALID-957',
#   'AP082EL01CFQALID-1498',
#   'DO274EL91APSALID-408'},
#  '14': {'AP082EL36CPVALID-1763',
#   'CO228EL88FBFALID-3411',
#   'NI743EL41IBYALID-5458',
#   'NO749EL20DJRALID-2279'},
#  '5': {'AP082EL13BLYALID-986',
#   'BL152EL82CRXALID-1817',
#   'NO749EL20DJRALID-2279',
#   'SA848EL83DOYALID-2416'},
#  '27': {'GE362EL02DCRALID-2097',
#   'NO749EL20DJRALID-2279',
#   'OL756EL65HDYALID-4834',
#   'SA848EL74DPHALID-2425'},
#  '30': {'BL152EL92QAPANID-28441',
#   'MA129HL24GBRANID-21673',
#   'SA848EL74DPHALID-2425',
#   'TO241EL36URZANID-32067'},
#  '29': {'DO274EL91APSALID-408',
#   'LE629EL54ANHALID-345',
#   'NO749EL20DJRALID-2279',
#   'VI962EL62EFDALID-2837'},
#  '45': {'MA172TL16AQPANID-36449',
#   'PY258HL33UKKANID-31841',
#   'WA362HB01BCSANID-36823',
#   'WA362HB98BCVANID-36826'},
#  '71': {'AP082EL45ANQALID-354',
#   'BE137ME32GBJANID-21665',
#   'GR087ME50OOV-9848',
#   'TO939EL00JELALID-6199'},
#  '100': {'BL301HL60VCPANID-32368',
#   'NE739EL08BGHANID-36920',
#   'OX378EL94CHTANID-37765',
#   'PH789EL10ASVALID-489'},
#  '104': {'NI743EL58GDHALID-4141',
#   'OP760EL41ERMALID-3158',
#   'TA910EL68EQLALID-3131',
#   'VI962SP07OVGANID-27590'},
#  '107': {'CH195EL91ZBGANID-35249',
#   'HP467EL79JUQALID-6620',
#   'NI743EL12AHFALID-187',
#   'NI743EL61YYOANID-35174'},
#  '132': {'BI171EL36CRRANID-38109',
#   'LO651EL09IIWANID-42358',
#   'NI743EL87GCEALID-4112',
#   'TA909EL37BFEANID-36887'},
#  '146': {'BL152EL91UPWANID-32012',
#   'BL152EL92QAPANID-28441',
#   'NI743EL08ORJANID-27489',
#   'SA848EL71FSEANID-21426'},
#  '156': {'MA172TL16AQPANID-36449',
#   'MA172TL60XAPANID-33763',
#   'MA172TL78VRHANID-32797',
#   'NE739EL25CSCANID-38120'},
#  '193': {'BL334HL71VNSANID-32742',
#   'BL334HL74VNPANID-32654',
#   'BL334HL75VNOANID-32653',
#   'KI592HL36UVVANID-32181'},
#  '205': {'AS100EL70BNPALID-1029',
#   'MA172TL16AQPANID-36449',
#   'SI876EL94DSJALID-2505',
#   'TR212TL41ZHAANID-35402'},
#  '209': {'BM137SP27DPCANID-38736',
#   'LI884SP24BVBANID-37429',
#   'SI876EL08DRVALID-2491',
#   'TE440HL78ASBANID-36499'},
#  '225': {'HT234EL32TRFANID-31278',
#   'IN513EL71BRKALID-1128',
#   'SH054EL88KNNALID-7111',
#   'SO888EL68IETALID-5531'},
#  '253': {'BL152EL01CHMANID-37758',
#   'BL152EL85CRUALID-1814',
#   'BL152EL91UPWANID-32012',
#   'BL152EL92QAPANID-28441'},
#  '218': {'LG639EL14YKZANID-34785',
#   'NE739EL01BSCANID-37331',
#   'SK880EL85DSSALID-2514',
#   'SP892EL85EICALID-2914'},
#  '261': {'CA192EL53IFIALID-5546',
#   'CR241EL94CVHALID-1905',
#   'GR087ME35PYA-10763',
#   'LE631EL63EYIALID-3336'},
#  '269': {'AP082EL95BEYALID-804',
#   'CO084HB87CLWANID-37877',
#   'NI743EL78YMJANID-34821',
#   'SO888EL36AVRALID-563'},
#  '297': {'AC016EL37CJYANID-37823',
#   'AC016EL55CJGANID-37805',
#   'CA189EL52JNZALID-6447',
#   'PR608EL66MKJANID-45729'},
#  '327': {'GR087ME48TTN-13350',
#   'IM333EL47FIMANID-39941',
#   'OZ114EL14FYFANID-21583',
#   'SW437SP07GSQANID-41068'},
#  '334': {'AP082EL07BMEALID-992',
#   'AP082EL35CPWALID-1764',
#   'CA189EL23EWAALID-3276',
#   'SO889EL26BHPALID-873'},
#  '340': {'EX320EL89EPQALID-3110',
#   'FU348EL64GKTALID-4335',
#   'HP467EL74JYRALID-6725',
#   'HT468EL26TCBANID-30550'},
#  '358': {'CA189EL23EWAALID-3276',
#   'KI593EL28EKHALID-2971',
#   'KI593EL69ASKANID-36520',
#   'SA850EL73EMKALID-3026'},
#  '359': {'AS100EL25AOKALID-374',
#   'BL152EL67KCUALID-6832',
#   'NE739EL37AZMALID-662',
#   'NO749EL33AZQALID-666'},
#  '424': {'GR087ME42UBL-13556',
#   'GR087ME77SRM-12621',
#   'GR087ME84TKL-13114',
#   'TO337TB56DKDANID-38600'},
#  '447': {'EL086ME79MEE-8219',
#   'GR087ME41QJI-11057',
#   'NE739EL06ORLANID-27491',
#   'PH789EL03ATCALID-496'},
#  '509': {'EL086ME81QHU-11017',
#   'GE362EL03DCQALID-2096',
#   'LO651EL41FEWANID-39843',
#   'WE980EL77DUWANID-38889'},
#  '523': {'CH460TB72BXBANID-37487',
#   'EL086ME41UYOANID-14157',
#   'PO186TL93BSKANID-37339',
#   'VI385HL02ZMJANID-35565'},
#  '528': {'BL152EL87CRSALID-1812',
#   'MU128TB88FFZANID-21109',
#   'RE215SP31TBWANID-30545',
#   'WE133EL60ADJANID-36029'},
#  '534': {'AC016EL06YHLANID-34693',
#   'AC016EL96SVNANID-30384',
#   'CL225EL94ZQNANID-35686',
#   'TO939EL97UAGANID-31518'},
#  '546': {'HO352HL05XVYANID-34375',
#   'MA130HL07VUAANID-32891',
#   'MA130HL59XMEANID-34068',
#   'MA172TL16AQPANID-36449'},
#  '498': {'BL152EL87CRSALID-1812',
#   'HT468EL25TCCANID-30551',
#   'NO749EL32AZRALID-667',
#   'NO749EL33AZQALID-666'},
#  '550': {'MO486TL60FHZANID-39930',
#   'NA220HL67AKUANID-36289',
#   'NA220HL81AZQANID-36718',
#   'SA848EL77EGKANID-39189'},
#  '552': {'BL152EL67KCUALID-6832',
#   'BL152EL92QAPANID-28441',
#   'EL180SP01UXEANID-32215',
#   'OI176TL53CUWANID-38189'},
#  '545': {'BL152EL67KCUALID-6832',
#   'CU302HL02VEVANID-32426',
#   'SA848EL46BEVANID-36878',
#   'TO939EL52VGTANID-32476'},
#  '582': {'BL152EL24BDVALID-775',
#   'BL152EL92QAPANID-28441',
#   'HP467EL74JYRALID-6725',
#   'SA848EL88BBJALID-711'},
#  '583': {'AP082EL34CPXALID-1765',
#   'BL152EL24BDVALID-775',
#   'BL152EL77CSCALID-1822',
#   'BL152EL85CRUALID-1814'},
#  '596': {'BL334HL15DPOANID-38748',
#   'MA129HL23GBSANID-21674',
#   'SE143HB46PBLANID-27751',
#   'VI385HL02ZMJANID-35565'},
#  '594': {'AD029EL42BKVALID-957',
#   'BE137ME32GBJANID-21665',
#   'FU348EL86FUNALID-3913',
#   'SA848EL74DPHALID-2425'},
#  '602': {'CO228EL88FBFALID-3411',
#   'GR087ME46XLTANID-15852',
#   'HT468EL25TCCANID-30551',
#   'TO939EL00JELALID-6199'},
#  '608': {'BL301HL54VCVANID-32374',
#   'NI743EL12XNZANID-34133',
#   'SA848EL86BBLALID-713',
#   'TR212TL41ZHAANID-35402'},
#  '616': {'AT103EL26BNHANID-37186',
#   'CA189EL30CVTANID-38214',
#   'PA216SP28TBZANID-30548',
#   'PO186TL84DQTANID-38779'},
#  '617': {'BM137SP58PIRANID-27939',
#   'NE739EL06BGJANID-36922',
#   'RU329SP81VNIANID-32647',
#   'SA395EL63ZGEANID-35380'},
#  '631': {'BL152EL67KCUALID-6832',
#   'BL152EL92QAPANID-28441',
#   'SA850EL08DXNANID-38958',
#   'SE861EL36DQTALID-2463'},
#  '634': {'ED290EL00CYXALID-1999',
#   'GE362EL95DCYALID-2104',
#   'SI876EL03DSAALID-2496',
#   'SO888EL63EBGALID-2736'},
#  '636': {'DE367EL16DXFANID-38950',
#   'EL086ME24LJF-7674',
#   'EL086ME81QHU-11017',
#   'SO887EL49DXYALID-2650'},
#  '650': {'HP467EL88JUHALID-6611',
#   'LO651EL03DGMALID-2196',
#   'SE861EL62DPTALID-2437',
#   'TI878SP48BUDANID-37405'},
#  '65': {'CA406HL83ZUUANID-35801',
#   'LA196HL44YNRANID-34855',
#   'LE361TB26EIJANID-39240',
#   'PH789EL28AATANID-35956'},
#  '181': {'CA189EL23AGUALID-176',
#   'GR087ME12TCPANID-30563',
#   'MO726EL42YNTANID-34857',
#   'MO726EL77VNMANID-32651'},
#  '673': {'CL225EL32CTVALID-1867',
#   'CL225EL36CTRALID-1863',
#   'PH789EL56ABRALID-43',
#   'PH789EL83DLCALID-2316'},
#  '679': {'GR087ME31QCA-10867',
#   'GR087ME45UBI-13553',
#   'GR087ME76HIHANID-22521',
#   'NI477ME55FEIANID-39829'},
#  '714': {'BL152EL67KCUALID-6832',
#   'CA192EL50IFLALID-5549',
#   'NI743EL96GRFALID-4503',
#   'PH789EL71ABCALID-28'},
#  '723': {'GR087ME01WUGANID-15397',
#   'GR087ME02WUFANID-15396',
#   'GR087ME59XDOANID-15639',
#   'GR087ME93XJYANID-15805'},
#  '788': {'FU348EL64GKTALID-4335',
#   'IM333EL06DIFANID-38550',
#   'PE224TB49TIWANID-30874',
#   'PO186TL31TJOANID-31100'},
#  '131': {'BL152EL08FQTANID-21389',
#   'BL152EL67KCUALID-6832',
#   'MO115EL76FVVANID-21521',
#   'NE739EL06ORLANID-27491'},
#  '823': {'BR168EL80HJBANID-41589',
#   'NI743EL42IBXALID-5457',
#   'SA850EL19EKQALID-2980',
#   'TO337TB56DKDANID-38600'},
#  '824': {'HP467EL22JDPALID-6177',
#   'NO749EL67JFSALID-6232',
#   'SO887EL37DUOALID-2562',
#   'TI930EL82BBPALID-717'},
#  '844': {'EL086ME09VWWANID-14789',
#   'EL086ME62VJHANID-14436',
#   'EL086ME90VMBANID-14508',
#   'GR087ME85OVE-10013'},
#  '859': {'CA192EL24IODALID-5775',
#   'CA192EL59IMUALID-5740',
#   'MA015EL35JKUALID-6364',
#   'MA015EL39JKQALID-6360'},
#  '874': {'IN254HL79UIQANID-31795',
#   'OX378HL89BSOANID-37343',
#   'TE440HL84ARVANID-36493',
#   'TI375SP35EEEANID-39131'},
#  '878': {'AC016EL51CPGALID-1748',
#   'HP467EL57AUWALID-542',
#   'SA848EL06BIJALID-893',
#   'SA848EL55JGEALID-6244'},
#  '902': {'AS100EL31JSQALID-6568',
#   'MA129HL24GBRANID-21673',
#   'MA130HL31AQAANID-36434',
#   'NO749EL54BENANID-36870'},
#  '910': {'NA451HB82BDLANID-36842',
#   'RM139TB36TYTANID-31479',
#   'RM139TB62UBPANID-31553',
#   'WA362HB70XPPANID-34198'},
#  '932': {'BL152EL23BDWALID-776',
#   'BL152EL67KCUALID-6832',
#   'PA216SP28TBZANID-30548',
#   'PO186TL33SQGANID-30255'},
#  '933': {'BL152EL91UPWANID-32012',
#   'QU369EL94AJTANID-36253',
#   'SA848EL73DPIALID-2426',
#   'SA850EL25BFQANID-36901'},
#  '934': {'AP082EL37CPUALID-1762',
#   'GR087ME70XORANID-15928',
#   'SA127TB30FEJANID-21067',
#   'VI962EL62EFDALID-2837'},
#  '974': {'GO439HL01AREANID-36476',
#   'MA129HL25GBQANID-21672',
#   'TO939EL52VGTANID-32476',
#   'VI385HL02ZINANID-35446'},
#  '981': {'DI271EL17CYGALID-1982',
#   'EL086ME17UHEANID-31757',
#   'NE739EL70KMFANID-43889',
#   'SE861EL70DPLALID-2429'},
#  '990': {'GR023EL39IFWALID-5560',
#   'JU117EL85EUOANID-20812',
#   'PH789EL67ABGALID-32',
#   'TA912EL82AXTALID-617'},
#  '996': {'AP078EL56EQXALID-3143',
#   'NI743EL25HFMALID-4874',
#   'NI743EL48GTBALID-4551',
#   'TA909EL88EPRALID-3111'},
#  '1000': {'AD429EL53ESWANID-39525',
#   'NE343TL04AYTANID-36695',
#   'NE343TL08CLBANID-37856',
#   'WA351SP55YRCANID-34944'},
#  '1003': {'EX335TL07AFKANID-36080',
#   'NE343TL19AEYANID-36068',
#   'PO186TL40ZHBANID-35403',
#   'SW459TL33BJEANID-37038'},
#  '1033': {'BE139SP51GFKANID-40583',
#   'BL368HL62DZHANID-39004',
#   'MO486TL59FIAANID-39931',
#   'OT882SP49GFMANID-40585'},
#  '1005': {'AS100EL76EGLANID-39190',
#   'BE129EL01TOOANID-31205',
#   'FU348EL30ZHLANID-35415',
#   'MA129HL38CVLANID-38206'},
#  '1053': {'HP467EL57JZIALID-6742',
#   'HP467EL70HPHALID-5129',
#   'HP467EL71HPGALID-5128',
#   'NE739EL06ORLANID-27491'},
#  '1067': {'BL152EL67KCUALID-6832',
#   'MD150SP14PKJANID-27983',
#   'NE739EL06ORLANID-27491',
#   'SA848EL49AVEALID-550'},
#  '1068': {'CA189EL95BSIANID-37337',
#   'SA850EL00DXVANID-38966',
#   'SA850EL01DXUANID-38965',
#   'SA850EL04DXRANID-38962'},
#  '1088': {'BE129EL01TOOANID-31205',
#   'ED384ME34ELXANID-39332',
#   'ED384ME48ELJANID-39318',
#   'MA172TL51XAYANID-33772'},
#  '1089': {'AP082EL39CPSALID-1760',
#   'FU348EL84FUPALID-3915',
#   'SA848EL33BHIALID-866',
#   'SA848EL88DOTALID-2411'},
#  '1099': {'AP082EL11BMAALID-988',
#   'BL152EL02JIFALID-6297',
#   'BL152EL77CSCALID-1822',
#   'SA848EL88DOTALID-2411'},
#  '1105': {'BL152EL67KCUALID-6832',
#   'GR087ME36QVB-11362',
#   'GR087ME47QUQ-11351',
#   'GR087ME65QTY-11333'},
#  '1122': {'CA189EL06JPTALID-6493',
#   'NI743EL92AHZALID-207',
#   'SA848EL28JHFALID-6271',
#   'TE913EL90ELTALID-3009'},
#  '1128': {'BL152EL87CRSALID-1812',
#   'BL152EL92QAPANID-28441',
#   'SA848EL54JGFALID-6245',
#   'SE143HB19OYQANID-27678'},
#  '1133': {'GR087ME11SIM-12387',
#   'LG639EL06APDALID-393',
#   'PH789EL83AAQALID-16',
#   'SA848EL71FSEANID-21426'},
#  '1140': {'BL152EL67KCUALID-6832',
#   'GO360TB19XNSANID-34120',
#   'SI138TB02ORPANID-27495',
#   'WE133EL60ADJANID-36029'},
#  '1152': {'NI743EL09ORIANID-27488',
#   'OG370TL34BJDANID-37037',
#   'PO186TL76VRJANID-32799',
#   'SW459TL33BJEANID-37038'},
#  '1198': {'DI126TB91FJSANID-21206',
#   'DI126TB95FJOANID-21202',
#   'DI126TB98FJLANID-21199',
#   'NE739EL01BSCANID-37331'},
#  '1213': {'DI126TB31FIEANID-21166',
#   'KO156HL39PRCANID-28194',
#   'MA129HL25GBQANID-21672',
#   'MA130HL30GBLANID-21667'},
#  '1247': {'KO238HL71TXKANID-31444',
#   'NE739EL48GFNANID-40586',
#   'NE739EL70KMFANID-43889',
#   'NE739EL71KMEANID-43888'},
#  '1254': {'BL152EL67KCUALID-6832',
#   'KI442EL66ASNANID-36523',
#   'KI593EL69ASKANID-36520',
#   'NE739EL98NRTANID-47131'},
#  '1227': {'SH866EL16YWLANID-35085',
#   'WA362HB68XPRANID-34200',
#   'WA362HB69XPQANID-34199',
#   'WA362HB70XPPANID-34198'},
#  '1255': {'GR087ME75LWQ-8023',
#   'GW166HB93QEKANID-28587',
#   'LG639EL79AQEALID-420',
#   'SE143HB57PBAANID-27740'},
#  '1260': {'BL301HL53VCWANID-32375',
#   'PA775EL01HRYALID-5198',
#   'PA775EL99HSAALID-5200',
#   'TO241HL10ZPXANID-35670'},
#  '1323': {'MA129HL24GBRANID-34127',
#   'NE739EL06ORLANID-27491',
#   'PO389TL10BRTANID-37320',
#   'WT402SP46ZSJANID-35738'},
#  '1334': {'PH789EL52DVVANID-38914',
#   'TE440HL16AYHANID-36682',
#   'TE440HL28AXVANID-36669',
#   'WA362HB69XPQANID-34199'},
#  '1358': {'KE239HL14ZPTANID-35666',
#   'NE739EL02BSBANID-37330',
#   'NE739EL06BGJANID-36922',
#   'TA907EL65CUKANID-38180'},
#  '1364': {'KI592HL36UVVANID-32181',
#   'KI592HL42UVPANID-32175',
#   'KI592HL50UVHANID-32167',
#   'KI592HL51UVGANID-32166'},
#  '1369': {'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'RM139TB81UAWANID-31534',
#   'SA848EL40BMTANID-37172'},
#  '1398': {'BL334HL71VNSANID-32740',
#   'KI592HL36UVVANID-32181',
#   'OI176TL53CUWANID-38189',
#   'RU329SP13VMCANID-32615'},
#  '1423': {'FU298HL78AKJANID-36271',
#   'KE239HL13ZPUANID-35667',
#   'PH789EL28AATANID-35956',
#   'SI182HL10QPHANID-28870'},
#  '1426': {'BL152EL92QAPANID-28441',
#   'BL368HL59DZKANID-39007',
#   'BL368HL60DZJANID-39006',
#   'NI213HL28XJNANID-33999'},
#  '1468': {'NE739EL06ORLANID-27491',
#   'WA362HB12BCHANID-36812',
#   'WA362HB13BCGANID-36811',
#   'WA362HB69XPQANID-34199'},
#  '1457': {'HP467EL33ZPAANID-35646',
#   'HP467EL36BJBANID-37036',
#   'HP467EL37BJAANID-37035',
#   'RM139TB80UAXANID-31535'},
#  '1476': {'EL086ME21ATIANID-18076',
#   'GR087ME16ATNANID-18081',
#   'GR087ME36PUD-10662',
#   'GR087ME39QBS-10859'},
#  '1477': {'BL152EL91UPWANID-32012',
#   'CL225EL93ZQOANID-35687',
#   'HO352HL07XVWANID-34373',
#   'SA848EL55JGEALID-6244'},
#  '1480': {'GO439HL01AREANID-36476',
#   'NE739EL06ORLANID-27491',
#   'NE739EL96CHRANID-37763',
#   'SA848EL55JGEALID-6244'},
#  '1485': {'AC016EL04YHNANID-34695',
#   'GE362EL02DCRALID-2097',
#   'NO749EL98FRDANID-21399',
#   'SI876EL08DRVALID-2491'},
#  '1535': {'EL086ME15UVSANID-14083',
#   'EL086ME30WDTANID-14968',
#   'EL086ME40WHFANID-15058',
#   'EL086ME64VUTANID-14734'},
#  '1556': {'PI885SP15BVKANID-37438',
#   'SW437SP40EXFANID-39644',
#   'SW437SP41EXEANID-39643',
#   'VA422HB50EPDANID-39418'},
#  '1561': {'BL152EL67KCUALID-6832',
#   'HA069TB53FHIANID-21144',
#   'NE739EL06ORLANID-27491',
#   'SE143HB64PATANID-27733'},
#  '1653': {'AP082EL35CPWALID-1764',
#   'CA189EL36IJVALID-5663',
#   'SO888EL58IBHALID-5441',
#   'TO939EL00JELALID-6199'},
#  '1663': {'CA189EL67EYEALID-3332',
#   'KI592HL36UVVANID-32181',
#   'SI876EL02DSBALID-2497',
#   'YA249HL84CIDANID-37776'},
#  '1706': {'MD150SP26DPDANID-38731',
#   'NE739EL40GFVANID-40594',
#   'NE739EL77UMOANID-31897',
#   'ZY007EL77HQWANID-41817'},
#  '1738': {'KI593EL69ASKANID-36520',
#   'PR372HL01AVAANID-36591',
#   'RE430HL54APDANID-36405',
#   'TE440HL16AYHANID-36682'},
#  '1778': {'LI884SP24BVBANID-37429',
#   'MA172TL16AQPANID-36449',
#   'MO486TL55FIEANID-39927',
#   'SA848EL40BMTANID-37172'},
#  '1782': {'DA255EL79HOYALID-5120',
#   'KO156HL43PQYANID-28190',
#   'MA130HL29GBMANID-21668',
#   'SA848EL54JGFALID-6245'},
#  '1835': {'NE739EL53BASANID-36746',
#   'WA362HB14BCFANID-36810',
#   'WA362HB16BCDANID-36808',
#   'WA362HB69XPQANID-34199'},
#  '1883': {'IM333EL06DIFANID-38550',
#   'MA172TL51XAYANID-33772',
#   'MA172TL77VRIANID-32798',
#   'MI714SP26FQZANID-40181'},
#  '1645': {'KI593EL69ASKANID-36520',
#   'NE739EL06ORLANID-27491',
#   'SA848EL55JGEALID-6244',
#   'ZT005EL48BCXALID-751'},
#  '1924': {'FU348EL64GKTALID-4335',
#   'NA737HB64LJNANID-44935',
#   'NE739EL01BSCANID-37331',
#   'ZE306HL89ZFEANID-35354'},
#  '1926': {'GA245HL84UATANID-31531',
#   'GA245HL85UASANID-31530',
#   'MA129EL71VCEANID-32356',
#   'SA395EL54ZGNANID-35389'},
#  '1146': {'NA390HB15ZAIANID-35220',
#   'RU329SP10VMFANID-32618',
#   'WA351SP63XEIANID-33860',
#   'WA351SP67XEEANID-33856'},
#  '1949': {'MO726EL77VNMANID-32651',
#   'NE739EL77UMOANID-31897',
#   'TE440HL16AYHANID-36682',
#   'TR212TL41ZHAANID-35402'},
#  '1976': {'NE739EL06ORLANID-27491',
#   'SE143HB47PBKANID-27750',
#   'TE440HL78ASBANID-36499',
#   'WA362HB07BCMANID-36817'},
#  '1985': {'AD029EL34BLDALID-965',
#   'AP082EL35CPWALID-1764',
#   'AP082EL45ANQALID-354',
#   'BL152EL10FQRANID-21387'},
#  '1986': {'AC016EL90SVTANID-30390',
#   'AS100EL70BNPALID-1029',
#   'NE739EL28ETVANID-39556',
#   'NE739EL34AZPALID-665'},
#  '529': {'NI743EL09ORIANID-27488',
#   'PH789EL11ASUALID-488',
#   'SO888EL31AVWALID-568',
#   'TO939EL35TUYANID-31380'},
#  '2000': {'CA189EL60AUTALID-539',
#   'LO651EL05DGKALID-2194',
#   'PO186TL93BSKANID-37339',
#   'SW459TL33BJEANID-37038'},
#  '2020': {'GO439HL01AREANID-36476',
#   'PY258HL32UKLANID-31842',
#   'SO888EL24DYXALID-2675',
#   'SO888EL28DYTALID-2671'},
#  '2042': {'KI592HL36UVVANID-32181',
#   'LU168HL52CRBANID-38092',
#   'NE739EL06ORLANID-27491',
#   'OX378HL04BGLANID-36924'},
#  '2044': {'AP082EL95BEYALID-804',
#   'GO439HL01AREANID-36476',
#   'NA220HL29AXUANID-36668',
#   'WE133EL60ADJANID-36029'},
#  '1461': {'FU348EL09GBIALID-4090',
#   'NA220HL98AYZANID-36701',
#   'PY258HL26UKRANID-31904',
#   'SA850EL11DXKANID-38955'},
#  '2106': {'AD429EL53ESWANID-39525',
#   'CL225EL26CUBALID-1873',
#   'HP467EL91AAIALID-8',
#   'TD401EL26ZTDANID-35758'},
#  '1411': {'GR087ME02GGJANID-21795',
#   'GR087ME18GFTANID-21779',
#   'GR087ME71RUQ-12027',
#   'KE089ME09YZQANID-16889'},
#  '2124': {'BL301HL56VCTANID-32372',
#   'CL225EL93ZQOANID-35687',
#   'RM139TB39OUAANID-27558',
#   'SA395EL60ZGHANID-35383'},
#  '1691': {'KI442EL48BXZANID-37511',
#   'KI593EL28DPBANID-38728',
#   'LE446HL26AUBANID-36566',
#   'NE739EL91DUIANID-38875'},
#  '2184': {'CO291HL24YZZANID-35211',
#   'HO352HL83XPCANID-34185',
#   'HO352HL84XPBANID-34184',
#   'HO352HL88XOXANID-34180'},
#  '2262': {'BL152EL08FQTANID-21389',
#   'BL152EL24JHJALID-6275',
#   'BL152EL79CSAALID-1820',
#   'NO749EL67JFSALID-6232'},
#  '2279': {'BL334HL54VOJANID-32761',
#   'CA441HL95BKQANID-37078',
#   'GO426HL42AHXANID-36204',
#   'GO426HL43AHWANID-36201'},
#  '2405': {'CA189EL09JPQALID-6490',
#   'NI743EL72IRZANID-42635',
#   'PO017EL46YVHANID-35053',
#   'VI385HL03ZMIANID-35564'},
#  '2482': {'MA129EL98ANLANID-36358',
#   'MA129HL02UPLANID-31977',
#   'NE739EL80UMLANID-31894',
#   'SA395EL53ZGOANID-35390'},
#  '2537': {'CA189EL21HNIALID-5078',
#   'EL086ME29WDUANID-14969',
#   'MA145HL19PGIANID-27878',
#   'TO445HB51HZOANID-42114'},
#  '2556': {'BL152EL67KCUALID-6832',
#   'BL152EL87CRSALID-1812',
#   'SA848EL52BGPALID-847',
#   'SA848EL88BBJALID-711'},
#  '2567': {'GR087ME04KNVANID-24693',
#   'GR087ME18XBHANID-15580',
#   'GR087ME35XIIANID-15763',
#   'GR087ME36XELANID-15662'},
#  '2592': {'BL152EL10BEJALID-789',
#   'BL152EL12FQPANID-21385',
#   'BL152EL79CSAALID-1820',
#   'SA848EL71FSEANID-21426'},
#  '2616': {'NE739EL06BGJANID-36922',
#   'NE739EL91DUIANID-38875',
#   'SA848EL41BMSANID-37171',
#   'TI878SP48BUDANID-37405'},
#  '2620': {'EL086ME37ALAANID-17860',
#   'EL086ME38AKZANID-17859',
#   'EL086ME56MCDANID-25741',
#   'EL086ME73AJQANID-17824'},
#  '2622': {'GO439HL01AREANID-36476',
#   'IM333EL09DICANID-38547',
#   'NA220HL99AYYANID-36700',
#   'SA848EL55JGEALID-6244'},
#  '2525': {'BL152EL92QAPANID-28441',
#   'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'NO749EL14YHDANID-34685'},
#  '2655': {'BL152EL24BDVALID-775',
#   'BL152EL79CSAALID-1820',
#   'SA848EL79DPCALID-2420',
#   'SA848EL80DPBALID-2419'},
#  '2662': {'EL086ME13MGS-8285',
#   'LI228HL24TNRANID-31076',
#   'PY258HL21UKWANID-31853',
#   'WA362HB01BCSANID-36823'},
#  '2665': {'HO352HL88XOXANID-34180',
#   'NE739EL91DUIANID-38875',
#   'WA362HB12BCHANID-36812',
#   'WA362HB14BCFANID-36810'},
#  '2668': {'DH296SP80UXZANID-32236',
#   'DH296SP81UXYANID-32235',
#   'MI714SP16TRVANID-31299',
#   'SO887EL47DYAALID-2652'},
#  '2485': {'NO749EL67GEUANID-40567',
#   'PI885SP15BVKANID-37438',
#   'PO186TL76VRJANID-32799',
#   'SA850EL23EKMALID-2976'},
#  '1301': {'BL152EL91UPWANID-32012',
#   'NE739EL06ORLANID-27491',
#   'NI743EL58IIZALID-5641',
#   'SA848EL78DPDALID-2421'},
#  '2738': {'MD150SP03PKUANID-31121',
#   'MD150SP09PKOANID-31153',
#   'MD150SP26DPDANID-38731',
#   'MD150SP26DPDANID-38737'},
#  '2422': {'BE129EL01TOOANID-31205',
#   'BL152EL92QAPANID-28441',
#   'NO749EL29CRYANID-38116',
#   'SA850EL12DXJANID-38954'},
#  '2751': {'HA069TB57FHEANID-21140',
#   'NA220HL14TVTANID-31401',
#   'PE224TB55TIQANID-30868',
#   'TE440HL07CSUANID-38138'},
#  '2752': {'CA201SP49QNUANID-28831',
#   'EL180SP53QNQANID-28827',
#   'NO749EL07UDSANID-31663',
#   'PH789EL46KPDALID-7153'},
#  '2754': {'NO034EL83QQIANID-28897',
#   'PO186TL25BBUANID-36797',
#   'SE143HB19OYQANID-27678',
#   'TE440HL28AXVANID-36669'},
#  '2603': {'DE262EL07JTOALID-6592',
#   'KY149SP19PKEANID-31180',
#   'NA220HL66BTLANID-37383',
#   'WA351SP64XEHANID-33859'},
#  '2799': {'CA192EL30IGFALID-5569',
#   'MO115EL83FVOANID-21514',
#   'NO749EL67JFSALID-6232',
#   'SA848EL67FSIANID-21430'},
#  '2806': {'FU348EL17BJUANID-37054',
#   'NE739EL06BGJANID-36922',
#   'NE739EL06ORLANID-27491',
#   'NE739EL07BGIANID-36921'},
#  '2808': {'BL152EL08FQTANID-21389',
#   'HP467EL66BZHALID-1333',
#   'IN513EL50CDTALID-1449',
#   'SA848EL72DPJALID-2427'},
#  '2832': {'CA189EL61JZEALID-6738',
#   'HP467EL36BJBANID-37036',
#   'HP467EL37BJAANID-37035',
#   'SO887EL47DYAALID-2652'},
#  '2829': {'AC016EL06YHLANID-34693',
#   'KI593EL68ASLANID-36521',
#   'SA850EL73EMKALID-3026',
#   'TA909EL14XNXANID-34131'},
#  '2763': {'BL152EL67KCUALID-6832',
#   'GR087ME57LHY-7641',
#   'LI884SP24BVBANID-37429',
#   'NO749EL59JGAALID-6240'},
#  '2875': {'AC016EL97SVMANID-30383',
#   'CA189EL63HAEALID-4736',
#   'SA848EL79DPCALID-2420',
#   'WE980EL34KAFALID-6765'},
#  '2886': {'SA848EL33VTAANID-32842',
#   'SI876EL08DRVALID-2491',
#   'SO887EL48DXZALID-2651',
#   'TO939EL48JKHALID-6351'},
#  '2894': {'BL152EL91UPWANID-32012',
#   'BL152EL92QAPANID-28441',
#   'SA850EL73EMKALID-3026',
#   'SA850EL89CPQANID-38055'},
#  '2895': {'KI593EL68ASLANID-36521',
#   'SE143HB14OYVANID-27683',
#   'SE143HB19OYQANID-27678',
#   'YA996ME04BODANID-37226'},
#  '2940': {'CL225EL89ZQSANID-35691',
#   'MA129EL68VCHANID-32359',
#   'NA220HL39TFKANID-30638',
#   'VI385HL04ZMHANID-35563'},
#  '2968': {'BL301HL58VCRANID-32370',
#   'KE239HL15ZPSANID-35665',
#   'RU329SP81VNIANID-32647',
#   'ST376HL50YBXANID-34547'},
#  '3037': {'BL152EL92QAPANID-28441',
#   'BL334HL15VPWANID-32768',
#   'BL334HL54VOJANID-32761',
#   'OX378HL30CKFANID-37834'},
#  '495': {'EV443EL70JDPANID-42974',
#   'MO486TL58FIBANID-39924',
#   'SA850EL95CPKANID-38049',
#   'TA909EL41BFAANID-36883'},
#  '1912': {'AR353TL80DQXANID-38783',
#   'KE239HL16ZPRANID-35664',
#   'SW446TB43FAYANID-39741',
#   'TO337TB56DKDANID-38600'},
#  '3058': {'CA189EL60AUTALID-539',
#   'NO749EL33AZQALID-666',
#   'SA848EL32CRVANID-38113',
#   'SA848EL54JGFALID-6245'},
#  '3074': {'AS100EL73JBQALID-6126',
#   'LA196HL11CKYANID-37853',
#   'SA850EL73EMKALID-3026',
#   'TH170HL91JKMANID-43162'},
#  '2758': {'BL152EL81CRYALID-1818',
#   'BL152EL85CRUALID-1814',
#   'SA848EL88DOTALID-2411',
#   'SO888EL72KVVALID-7327'},
#  '3103': {'CL225EL32CTVALID-1867',
#   'LO651EL07DGIALID-2192',
#   'NO749EL33AZQALID-666',
#   'SE143HB63PAUANID-27734'},
#  '3114': {'BL152EL85CRUALID-1814',
#   'EL086ME31LIY-7667',
#   'EL086ME73LHI-7625',
#   'GR087ME76LHF-7622'},
#  '3115': {'BA380HB18EIRANID-39248',
#   'DE329HB49DGOANID-38506',
#   'MO722HB00DTZANID-38866',
#   'YV088HB65CMSANID-37899'},
#  '3129': {'NA220HL36AXNANID-36661',
#   'NA220HL88THJANID-30694',
#   'NE739EL06ORLANID-27491',
#   'QU369EL94AJTANID-36253'},
#  '3151': {'RM139TB51OTOANID-27546',
#   'RM139TB65OTAANID-27532',
#   'RM139TB67OSYANID-27530',
#   'RM139TB71OSUANID-27526'},
#  '3161': {'CR253HL91BDCANID-36833',
#   'LI228HL25TNQANID-31075',
#   'NE739EL06BGJANID-36922',
#   'NE739EL77UMOANID-31897'},
#  '3119': {'MA129HL27QDCANID-28529',
#   'NA220HL36AXNANID-36661',
#   'NA220HL36TFNANID-30641',
#   'SA848EL74DPHALID-2425'},
#  '3177': {'CA189EL28GMDALID-4371',
#   'MA129HL24GBRANID-21673',
#   'MA696HL21BFUANID-36907',
#   'PY258HL18UKZANID-31856'},
#  '3194': {'EL086ME01VTIANID-14697',
#   'EL086ME64WCLANID-14934',
#   'HP467EL90AAJALID-9',
#   'WE980EL42JZXALID-6757'},
#  '3197': {'AP082EL34BDLALID-765',
#   'CA189EL45IJMALID-5654',
#   'HO466EL80FYPALID-4019',
#   'TE440HL86BKZANID-37088'},
#  '3201': {'KI442EL66ASNANID-36523',
#   'PO389TL11BRSANID-37319',
#   'SI876EL08DRVALID-2491',
#   'SO887EL48DUDALID-2551'},
#  '3202': {'RM139TB41OTYANID-27556',
#   'RM139TB53OTMANID-27544',
#   'RM139TB58OTHANID-27539',
#   'RM139TB66OSZANID-27531'},
#  '3215': {'AD429EL53ESWANID-39525',
#   'CO291SP46UZHANID-32270',
#   'HP467EL74JYRALID-6725',
#   'PO186TL40ZHBANID-35403'},
#  '3220': {'NE739EL01BSCANID-37331',
#   'NE739EL06BGJANID-36922',
#   'NI743EL09ORIANID-27488',
#   'NI743EL12XNZANID-34133'},
#  '3243': {'AP082EL35CPWALID-1764',
#   'AS100EL75JBOALID-6124',
#   'BL152EL08FQTANID-21389',
#   'DE262EL08JTNALID-6591'},
#  '3232': {'ES231HL05TOKANID-31115',
#   'HP467EL74JYRALID-6725',
#   'YA249HL98UXHANID-32218',
#   'ZE306HL92VJBANID-32536'},
#  '3257': {'BL334HL82ZQZANID-35698',
#   'CA327HL30VLLANID-32598',
#   'CA327HL31VLKANID-32597',
#   'TE440HL78ASBANID-36499'},
#  '3265': {'BO153HB03TOMANID-31200',
#   'ED290EL00CYXALID-1999',
#   'PH789EL56DMDALID-2343',
#   'PH789EL62DLXALID-2337'},
#  '3269': {'BL301HL48VDBANID-32380',
#   'BL301HL55VCUANID-32373',
#   'GR087ME16OQD-9882',
#   'NE739EL50BAVANID-36749'},
#  '3270': {'LA196HL75XTGANID-34293',
#   'MA172TL44HOHANID-41725',
#   'OI176TL54CUVANID-38188',
#   'SO888EL52MSPANID-46036'},
#  '3289': {'EL086ME02JBLANID-23695',
#   'GR087ME38WSVANID-15360',
#   'RM139TB00ZMLANID-35567',
#   'RM139TB57OTIANID-27540'},
#  '3295': {'CA201SP48QNVANID-28832',
#   'KO238HL71TXKANID-31444',
#   'SA395EL01ZESANID-35339',
#   'WI328SP17VLYANID-32611'},
#  '3306': {'GR087ME35WWUANID-15463',
#   'GR087ME82WUZANID-15416',
#   'NO749EL30CRXANID-38115',
#   'NO749EL63GEYANID-40571'},
#  '3309': {'GR087ME04TZB-13494',
#   'GR087ME95SQU-12603',
#   'HP467EL74JYRALID-6725',
#   'WE133EL60ADJANID-36029'},
#  '3310': {'BL152EL23BDWALID-776',
#   'BL152EL67KCUALID-6832',
#   'BL152EL87CRSALID-1812',
#   'SA850EL31ERWALID-3168'},
#  '3314': {'AP082EL37BDIALID-762',
#   'BL152EL24BDVALID-775',
#   'OL756EL41JOKALID-6458',
#   'SE861EL58DPXALID-2441'},
#  '3336': {'CL225EL93ZQOANID-35687',
#   'RE408SP88ENRANID-39378',
#   'YA249HL74XDXANID-33849',
#   'ZE306HL83ZFKANID-35360'},
#  '3345': {'CA189EL56BAPANID-36743',
#   'KO238HL70TXLANID-31445',
#   'LE631EL35ERSALID-3164',
#   'SA850EL98FINALID-3601'},
#  '3350': {'BI171EL39CROANID-38106',
#   'KI593EL69ASKANID-36520',
#   'NI743EL12XNZANID-34133',
#   'SE861EL68DPNALID-2431'},
#  '3364': {'HA069TB58FHDANID-21139',
#   'RM139TB68OSXANID-27529',
#   'TR305TB57VZUANID-33067',
#   'TR305TB72VZFANID-33052'},
#  '3402': {'NI743EL09ORIANID-27488',
#   'NI743EL12AHFALID-187',
#   'NI743EL87GCEALID-4112',
#   'SO888EL04EWTALID-3295'},
#  '2355': {'FU298HL79AKIANID-36270',
#   'GR087ME78QEB-10920',
#   'PR353TL81XHMANID-33946',
#   'SA850EL93DYCANID-38973'},
#  '3380': {'NE739EL02BSBANID-37330',
#   'NE739EL06BGJANID-36922',
#   'NE739EL29ETUANID-39555',
#   'NE739EL97NRUANID-47132'},
#  '3443': {'OX378EL98YXDANID-35103',
#   'SA848EL55JGEALID-6244',
#   'SA848EL62FSNANID-21435',
#   'UN244SP97XOOANID-34171'},
#  '2756': {'AP082EL19BHWALID-880',
#   'SA848EL49AVEALID-550',
#   'SA848EL71FSEANID-21426',
#   'SH866EL22KQBALID-7177'},
#  '3458': {'AC016EL35MAAANID-45374',
#   'AC016EL53CJIANID-37807',
#   'BL152EL92QAPANID-28441',
#   'SA848EL45TFEANID-30631'},
#  '1740': {'CA189EL92EQLANID-20705',
#   'SA850EL73EMKALID-3026',
#   'SE143HB16OYTANID-27681',
#   'SE143HB19OYQANID-27678'},
#  '3469': {'BL152EL08FQTANID-21389',
#   'BL152EL24BDVALID-775',
#   'SO888EL26AWBALID-573',
#   'TO939EL52VGTANID-32476'},
#  '2092': {'MA130HL30AQBANID-36435',
#   'MA130HL31AQAANID-36434',
#   'SA848EL88BBJALID-711',
#   'TO141TB18OUVANID-27579'},
#  '3534': {'EL086ME16UNZANID-13882',
#   'GR087ME67SCM-12231',
#   'MI183ME15RXSANID-29762',
#   'MI183ME77RZEANID-29799'},
#  '3543': {'FU348EL31ZHKANID-35414',
#   'FU348EL35AIEANID-36212',
#   'GR087ME04RTJ-11994',
#   'PA775EL37VDMANID-32391'},
#  '3550': {'BL152EL67KCUALID-6832',
#   'BL334HL54VOJANID-32760',
#   'GR087ME32TUD-13366',
#   'MA129HL31GBKANID-21666'},
#  '3556': {'GR087ME27HKEANID-22570',
#   'GR087ME77QHY-11021',
#   'GR087ME83HIAANID-22514',
#   'GR087ME98HLHANID-22599'},
#  '3626': {'CA189EL50YYZANID-35185',
#   'HP467EL75JYQALID-6724',
#   'MO726EL42YNTANID-34857',
#   'WE133EL60ADJANID-36029'},
#  '3629': {'BL301HL53VCWANID-32375',
#   'BL301HL59VCQANID-32369',
#   'MA129HL08VILANID-32520',
#   'RM139TB24OUPANID-27573'},
#  '3615': {'EL086ME56QMP-11142',
#   'GR087ME35ISMANID-23462',
#   'GR087ME54QBD-10844',
#   'PE091ME20QCL-10878'},
#  '3654': {'MU128TB84FGDANID-21113',
#   'SA127TB95FFSANID-21102',
#   'SI138TB00ORRANID-27497',
#   'SI138TB02ORPANID-27495'},
#  '3693': {'BL152EL85CRUALID-1814',
#   'FU348EL24BJNANID-37047',
#   'GR087ME56HMXANID-22641',
#   'GR087ME94PZP-10804'},
#  '3701': {'MA172TL51XAYANID-33772',
#   'PO389TL14BRPANID-37316',
#   'SE143HB69PAOANID-27728',
#   'WA362HB01BCSANID-36823'},
#  '3719': {'BL334HL57VOGANID-32671',
#   'DR447HL31BBOANID-36780',
#   'PH789EL46KPDALID-7153',
#   'SI876EL94DSJALID-2505'},
#  '3730': {'NO749EL67JFSALID-6232',
#   'RM139TB36TYTANID-31479',
#   'RM139TB58OTHANID-27539',
#   'RM139TB66OSZANID-27531'},
#  '3742': {'TE440HL16AYHANID-36682',
#   'TE440HL17AYGANID-36681',
#   'TE440HL28AXVANID-36669',
#   'TE440HL86BKZANID-37088'},
#  '3768': {'RM139TB50OTPANID-27547',
#   'RM139TB61OTEANID-27536',
#   'RM139TB70OSVANID-27527',
#   'RM139TB71OSUANID-27526'},
#  '3761': {'GR087ME83HEEANID-22414',
#   'KE089ME54XPHANID-15944',
#   'PE091ME40XPVANID-15958',
#   'PE091ME41XPUANID-15957'},
#  '3773': {'AP082EL50ANLALID-349',
#   'HT468EL09JHYALID-6290',
#   'NE739EL07BGIANID-36921',
#   'SO887EL93DWGALID-2606'},
#  '3777': {'MA129HL24GBRANID-34127',
#   'MA130HL29AQCANID-36436',
#   'MA130HL31AQAANID-36434',
#   'OX378EL05YWWANID-35096'},
#  '3786': {'PH789EL05DKGALID-2294',
#   'PR814EL46ACBALID-53',
#   'SA848EL54JGFALID-6245',
#   'SO887EL62DXLALID-2637'},
#  '3791': {'MI714SP22PCJANID-27775',
#   'MI714SP60PETANID-27837',
#   'MI714SP70PEJANID-27827',
#   'NO749EL31AZSALID-668'},
#  '471': {'EL086ME46PIF-10352',
#   'GR087ME17QKG-11081',
#   'GR087ME35PEU-10263',
#   'GR087ME54QIV-11044'},
#  '3821': {'BL152EL08FQTANID-21389',
#   'BL152EL85CRUALID-1814',
#   'HP467EL74JYRALID-6725',
#   'SA848EL48AVFALID-551'},
#  '3870': {'MA129EL98ANLANID-36358',
#   'MA172TL16AQPANID-36449',
#   'NA220HL64AKXANID-36292',
#   'NA220HL99AYYANID-36700'},
#  '3877': {'AP082EL20BHVALID-879',
#   'AP082EL44ANRALID-355',
#   'BL152EL67KCUALID-6832',
#   'BL152EL83CRWALID-1816'},
#  '3900': {'GR087ME34ISNANID-23463',
#   'GR087ME43PTW-10655',
#   'GR087ME99QDG-10899',
#   'HP467EL74JYRALID-6725'},
#  '3944': {'GR087ME01WYCANID-15497',
#   'GR087ME25DCSANID-19672',
#   'GR087ME49CAWANID-18948',
#   'GR087ME80DELANID-19717'},
#  '3945': {'KE239HL16ZPRANID-35664',
#   'RM139TB67OSYANID-27530',
#   'RM139TB70OSVANID-27527',
#   'SA395EL16ZEDANID-35324'},
#  '3977': {'NI743EL08ORJANID-27489',
#   'NI743EL09ORIANID-27488',
#   'SO887EL56DTVALID-2543',
#   'SO888EL19DZCALID-2680'},
#  '4033': {'GR087ME45UBI-13553',
#   'GR087ME46XLTANID-15852',
#   'KE089ME25UFYANID-13673',
#   'KE089ME26UFXANID-13672'},
#  '4032': {'EL086ME12QGP-10986',
#   'EL086ME28JEHANID-23769',
#   'EL086ME80VUDANID-14718',
#   'EL086ME90PCR-10208'},
#  '4086': {'LG639EL24TVJANID-31391',
#   'NE739EL91DUIANID-38875',
#   'TO241EL60UBRANID-31555',
#   'TO241EL61UBQANID-31554'},
#  '4146': {'BU233HL22COJANID-37942',
#   'GR087ME21OPY-9877',
#   'HO352HL84XPBANID-34184',
#   'KI442EL53BXUANID-37506'},
#  '4172': {'NE739EL77UMOANID-31897',
#   'NE739EL83BFKALID-816',
#   'NE739EL99NRSANID-47130',
#   'SA848EL39XFGANID-33888'},
#  '4176': {'EX335TL14AFDANID-36073',
#   'NE739EL50BAVANID-36749',
#   'NI743EL12XNZANID-34133',
#   'OG370TL32BJFANID-37039'},
#  '4205': {'GR087ME27SLS-12471',
#   'GR087ME82SRH-12616',
#   'NI743EL02KBLALID-6797',
#   'NI743EL12AHFALID-187'},
#  '4224': {'AT214SP32TBVANID-30544',
#   'RM139TB38OUBANID-27559',
#   'RM139TB50OTPANID-27547',
#   'RM139TB67OSYANID-27530'},
#  '4226': {'CU302HL09VEOANID-32419',
#   'GR087ME32LUL-7966',
#   'GR087ME33LUK-7965',
#   'GR087ME95LVW-8003'},
#  '4232': {'AP082EL17BLUALID-982',
#   'AP082EL18BHXALID-881',
#   'AP082EL19BHWALID-880',
#   'AP082EL31BDOALID-768'},
#  '4233': {'EL086ME80QAD-10818',
#   'SA848EL40BMTANID-37172',
#   'WA351SP57XEOANID-33866',
#   'WA351SP66XEFANID-33857'},
#  '4245': {'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519',
#   'NE739EL96CHRANID-37763',
#   'SA850EL06DXPANID-38960'},
#  '4247': {'AT214SP32TBVANID-30544',
#   'HA069TB58FHDANID-21139',
#   'MA172OT86QMJANID-28794',
#   'SI138TB74OSRANID-27523'},
#  '4257': {'BE139SP50UJTANID-31824',
#   'KO238SP02TSJANID-31313',
#   'RA193SP33SUCANID-30346',
#   'TO337TB60DJZANID-38596'},
#  '4276': {'EL086ME60VJJANID-14438',
#   'GR087ME38TIJ-13060',
#   'GR087ME50XDXANID-15648',
#   'GR087ME72UAH-13526'},
#  '4285': {'MI714SP69PEKANID-27828',
#   'MI714SP70PEJANID-27827',
#   'NE739EL08BGHANID-36920',
#   'NI211TL39CNSANID-37925'},
#  '4312': {'GR087ME41UBM-13557',
#   'NI743EL08ORJANID-27489',
#   'OI176TL53CUWANID-38189',
#   'OI176TL54CUVANID-38188'},
#  '4337': {'HO352HL92XOTANID-34176',
#   'HP467EL91AAIALID-8',
#   'NE739EL07BGIANID-36921',
#   'PH789EL67ABGALID-32'},
#  '4344': {'SA127TB03FFKANID-21094',
#   'SA127TB30FEJANID-21067',
#   'SA127TB91FFWANID-21106',
#   'SA127TB93FFUANID-21104'},
#  '4343': {'EL086ME49PEG-10249',
#   'EL086ME89PCS-10209',
#   'EL086ME94PCN-10204',
#   'GR088ME85PCW-10213'},
#  '4345': {'PR445HL27AUAANID-36565',
#   'PR445HL28ATZANID-36564',
#   'PR445HL31ATWANID-36561',
#   'PR445HL32ATVANID-36560'},
#  '4353': {'BL152EL10FQRANID-21387',
#   'BL152EL27DHKANID-38529',
#   'CA189EL61JZEALID-6738',
#   'SA848EL40BMTANID-37172'},
#  '4402': {'GR087ME62SKJ-12436',
#   'GR087ME98TGB-13000',
#   'MI183ME68QYPANID-29111',
#   'MI183ME73QQSANID-28906'},
#  '4408': {'IM333EL08DIDANID-38548',
#   'IM333EL14DXHANID-38952',
#   'PY258HL33UKKANID-31841',
#   'SA850EL23EKMALID-2976'},
#  '4418': {'AC016EL98SVLANID-30382',
#   'BL152EL67KCUALID-6832',
#   'LI146HL92PHJANID-27905',
#   'SA848EL32CRVANID-38113'},
#  '4425': {'BL152EL81CRYALID-1818',
#   'BL152EL87CRSALID-1812',
#   'GR087ME57SZY-12841',
#   'PI885SP15BVKANID-37438'},
#  '4459': {'GR087ME95PZO-10803',
#   'PU293ME76DFNANID-38479',
#   'SA848EL85FRQANID-21412',
#   'SW437SP40EXFANID-39644'},
#  '4462': {'BM137SP63PIMANID-27934',
#   'NI743EL14CWJANID-38230',
#   'RU329SP89VNAANID-32639',
#   'SA848EL55JGEALID-6244'},
#  '4479': {'BL152EL85CRUALID-1814',
#   'IM333EL06DIFANID-38550',
#   'SA848EL71FSEANID-21426',
#   'SA848EL90FRLANID-21407'},
#  '4483': {'BL301HL61VCOANID-32367',
#   'MA130HL30AQBANID-36435',
#   'MA130HL31AQAANID-36434',
#   'VI385HL04ZMHANID-35563'},
#  '3705': {'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'NO749EL12BALALID-687',
#   'PH789EL30XFPANID-33897'},
#  '4503': {'HP467EL60MOLANID-45925',
#   'KE239HL14ZPTANID-35666',
#   'OX378EL96YXFANID-35105',
#   'UR116EL88FVJANID-21509'},
#  '4526': {'BL152EL92QAPANID-28441',
#   'CA189EL00LTRANID-45207',
#   'LG639EL02BVXANID-37457',
#   'PE783EL06LPPANID-45101'},
#  '4543': {'BL152EL28BDRALID-771',
#   'BL152EL67KCUALID-6832',
#   'BL152EL87CRSALID-1812',
#   'BL152EL92QAPANID-28441'},
#  '4555': {'CA189EL21HNIALID-5078',
#   'RM139TB61OTEANID-27536',
#   'RM139TB67OSYANID-27530',
#   'SI138TB00ORRANID-27497'},
#  '4559': {'KI442EL51BXWANID-37508',
#   'RA140TB15AMUANID-36341',
#   'RA140TB17AMSANID-36339',
#   'SE861EL60DPVALID-2439'},
#  '4564': {'HK438HL26GZPANID-41318',
#   'MA129HL00VUHANID-32966',
#   'MA129HL25VTIANID-32953',
#   'MA130HL15VTSANID-32958'},
#  '4569': {'AC016EL92SVRANID-30388',
#   'AC016EL95SVOANID-30385',
#   'AP082EL23AQIANID-36442',
#   'HP467EL74JYRALID-6725'},
#  '4576': {'AP082EL20BHVALID-879',
#   'RE215SP31TBWANID-30545',
#   'SA848EL28JHFALID-6271',
#   'SA848EL73DPIALID-2426'},
#  '4510': {'HP467EL75JYQALID-6724',
#   'LA196HL16CKTANID-37848',
#   'MA129HL86BOVANID-37244',
#   'MA129HL87BOUANID-37243'},
#  '4009': {'ED290EL01CYWALID-1998',
#   'HP467EL74JYRALID-6725',
#   'LO651EL90DGZALID-2209',
#   'PA216SP28TBZANID-30548'},
#  '4607': {'GR087ME17TFI-12981',
#   'GR087ME27SLS-12471',
#   'GR087ME65TDM-12933',
#   'GR087ME77RYG-12121'},
#  '4633': {'GR087ME11OQI-9887',
#   'GR087ME13OQG-9885',
#   'GR087ME41OPE-9857',
#   'GR087ME83OVG-10015'},
#  '4689': {'GO426HL40AHZANID-36177',
#   'GR087ME41UFIANID-13657',
#   'KE239HL16ZPRANID-35664',
#   'NE739EL07BGIANID-36921'},
#  '4698': {'BU233HL14TRXANID-31301',
#   'KI593EL67ASMANID-36522',
#   'SA850EL31ERWALID-3168',
#   'SE861EL60DPVALID-2439'},
#  '4742': {'CA199EL47EHOANID-39219',
#   'FA443HB64ASPANID-36528',
#   'OI176TL53CUWANID-38189',
#   'WT402SP40ZSPANID-35744'},
#  '4748': {'CO291SP46UZHANID-32270',
#   'NA220HL16IQHANID-42591',
#   'XT336TL70IVXANID-42737',
#   'XT336TL71IVWANID-42736'},
#  '4746': {'CA189EL09JPQALID-6490',
#   'EL086ME79VIQANID-14419',
#   'EL086ME92VLZANID-14506',
#   'MA130HL31AQAANID-36434'},
#  '4759': {'CA189EL28HNBALID-5071',
#   'HP467EL87AAMALID-12',
#   'RM139TB66OSZANID-27531',
#   'SA850EL31ERWALID-3168'},
#  '4766': {'LI884SP21BVEANID-37432',
#   'NI743EL16CWHANID-38228',
#   'PR445HL28ATZANID-36564',
#   'SW459TL33BJEANID-37038'},
#  '4511': {'CA199EL46EHPANID-39220',
#   'PA216SP28TBZANID-30548',
#   'SA851EL56GMXANID-40836',
#   'TO939EL35TUYANID-31380'},
#  '4782': {'GR087ME60IJVANID-23237',
#   'KI593EL68ASLANID-36521',
#   'SA848EL84FRRANID-21413',
#   'TA909EL14XNXANID-34131'},
#  '4801': {'CL225EL11AUQANID-36581',
#   'CL225EL95ZQMANID-35685',
#   'GR087ME55YUYANID-35044',
#   'LU168HL50CRDANID-38094'},
#  '4804': {'MU128TB86FGBANID-21111',
#   'MU128TB87FGAANID-21110',
#   'MU128TB88FFZANID-21109',
#   'MU128TB89FFYANID-21108'},
#  '4830': {'HA069TB58FHDANID-21139',
#   'RM139TB53OTMANID-27544',
#   'RM139TB66OSZANID-27531',
#   'RM139TB67OSYANID-27530'},
#  '4842': {'MA129HL17VTQANID-32957',
#   'ST376HL19YDCANID-34577',
#   'TE377HL27GRWANID-41048',
#   'YA249HL75XDWANID-33848'},
#  '4859': {'CL225EL05CUWALID-1894',
#   'PH789EL23XFWANID-33904',
#   'SA848EL28JHFALID-6271',
#   'SA848EL33VTAANID-32842'},
#  '4888': {'FU298HL75AKMANID-36274',
#   'SA848EL45TFEANID-30631',
#   'VA851EL05GLAANID-40775',
#   'ZE306HL88ZFFANID-35355'},
#  '4901': {'BA187TL29SQKANID-30253',
#   'EL086ME81QHU-11017',
#   'OX365TL70XTLANID-34298',
#   'PO186TL27BBSANID-36796'},
#  '4938': {'ED290EL03CYUALID-1996',
#   'HU469EL95ZBCANID-35245',
#   'KI593EL28DPBANID-38728',
#   'SO887EL57DTUALID-2542'},
#  '4953': {'GR087ME20QKD-11078',
#   'GR087ME23QKA-11075',
#   'MA172TL53XAWANID-33770',
#   'SA850EL31ERWALID-3168'},
#  '4967': {'BE139SP50UJTANID-31824',
#   'MA129HL02PSNANID-28231',
#   'MA130HL30AQBANID-36435',
#   'SE861EL60DPVALID-2439'},
#  '4612': {'NA220HL37TFMANID-30640',
#   'NA220HL39TFKANID-30638',
#   'NA220HL82THPANID-30700',
#   'NA220HL88THJANID-30694'},
#  '4999': {'EL086ME56WGPANID-15042',
#   'GR087ME12IADANID-22985',
#   'GR087ME48CETANID-19049',
#   'MI183ME45RDIANID-29233'},
#  '4448': {'GR087ME11PFS-10287',
#   'GR087ME24QJZ-11074',
#   'KE089ME74XSJANID-16024',
#   'MI183ME27QWIANID-29052'},
#  '5005': {'EL086ME18PND-10480',
#   'EL086ME56WGPANID-15042',
#   'GR087ME12IADANID-22985',
#   'MI183ME45RDIANID-29233'},
#  '5041': {'BU233HL12TRZANID-31303',
#   'BU233HL23COIANID-37941',
#   'LI884SP18BVHANID-37435',
#   'MD150SP26DPDANID-38731'},
#  '5048': {'NI743EL13CWKANID-38231',
#   'RM139TB36TYTANID-31479',
#   'RM139TB62OTDANID-27535',
#   'SE861EL62DPTALID-2437'},
#  '5064': {'LI228HL39ZKYANID-35509',
#   'NA220HL01TGWANID-30681',
#   'PY258HL21UKWANID-31853',
#   'TR212TL46TBHANID-31280'},
#  '4300': {'FU348EL20BJRANID-37051',
#   'MA172TL53XAWANID-33770',
#   'NI743EL09ORIANID-27488',
#   'SA127TB30FEJANID-21067'},
#  '5092': {'KI442EL41BYGANID-37518',
#   'MA129HL24GBRANID-21673',
#   'NA220HL23IQAANID-42584',
#   'WE980EL97AFUANID-36096'},
#  '5119': {'KI442EL91BKUANID-37083',
#   'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519',
#   'MA129EL99ANKANID-36357'},
#  '5151': {'GR087ME26SEB-12272',
#   'GR087ME28SDZ-12270',
#   'GR087ME36SDR-12262',
#   'GR087ME53SOO-12545'},
#  '5190': {'MI183ME12RXVANID-29765',
#   'MI183ME16SFJANID-29960',
#   'MI183ME19SFGANID-29957',
#   'MI183ME30SEVANID-29946'},
#  '5196': {'BU171EL78FHHANID-39906',
#   'CO291SP46UZHANID-32270',
#   'OL190HL04SRJANID-30275',
#   'OL190HL05SRIANID-30274'},
#  '5221': {'CL225EL02AFPANID-36091',
#   'CL225EL92ZQPANID-35688',
#   'RU329SP95VMUANID-32633',
#   'SI876EL08DRVALID-2491'},
#  '5269': {'GO426HL39AIAANID-36178',
#   'GO426HL40AHZANID-36177',
#   'GO426HL41AHYANID-36176',
#   'HO352HL82XHLANID-33945'},
#  '3642': {'BU233HL14TRXANID-31301',
#   'LI884SP16BVJANID-37437',
#   'PI885SP88CTNANID-38157',
#   'PO389TL59YYQANID-35176'},
#  '5292': {'MI714SP16TRVANID-31299',
#   'MI714SP26FQZANID-40165',
#   'MI714SP26FQZANID-40180',
#   'MI714SP67PEMANID-27830'},
#  '5307': {'CL225EL86ZQVANID-35694',
#   'HP467EL57JZIALID-6742',
#   'PH789EL67ABGALID-32',
#   'SI876EL05DRYALID-2494'},
#  '5273': {'GR087ME01GCOANID-21696',
#   'GR087ME32SLN-12466',
#   'GR087ME89SNE-12509',
#   'GR087ME99GGMANID-21798'},
#  '4655': {'CL225EL11AUQANID-36581',
#   'OX378HL11ABKANID-35973',
#   'OX378HL11HEAANID-41458',
#   'TA909EL34BFHANID-36890'},
#  '5381': {'GR087ME01QKW-11097',
#   'GR087ME03HLCANID-22594',
#   'GR087ME58QMN-11140',
#   'GR087ME75QEE-10923'},
#  '5392': {'EL086ME29PQO-10569',
#   'EL086ME81IMWANID-23316',
#   'GR087ME28HKDANID-22569',
#   'MI183ME26SBDANID-29850'},
#  '5414': {'HP467EL75JYQALID-6724',
#   'KI442EL90BORANID-37240',
#   'NI743EL08ORJANID-27489',
#   'PA775EL41VDIANID-32387'},
#  '5418': {'BL152EL67KCUALID-6832',
#   'FU348EL21YWGANID-35080',
#   'RU329SP92VMXANID-32636',
#   'WA362HB16BCDANID-36808'},
#  '5423': {'MA129EL67VCIANID-32360',
#   'MA130HL31AQAANID-36434',
#   'NA220HL35AXOANID-36662',
#   'TR212TL46TBHANID-31281'},
#  '5431': {'BL301HL44VDFANID-32384',
#   'BL301HL49VDAANID-32379',
#   'BL301HL60VCPANID-32368',
#   'OX378EL99YXCANID-35102'},
#  '5433': {'RM139TB40OTZANID-27557',
#   'RM139TB41OTYANID-27556',
#   'RM139TB62UBPANID-31553',
#   'RM139TB79UAYANID-31536'},
#  '5439': {'RM139TB22OURANID-27575',
#   'RM139TB23OUQANID-27574',
#   'RM139TB32OUHANID-27565',
#   'RM139TB76UBBANID-31539'},
#  '5425': {'EL086ME25VKSANID-14473',
#   'EL086ME46UUNANID-14052',
#   'EL086ME51WCYANID-14947',
#   'EL086ME90VMBANID-14508'},
#  '2865': {'EL086ME73MJEANID-25924',
#   'EL086ME77MJAANID-25920',
#   'KI593EL68ASLANID-36521',
#   'SA850EL73EMKALID-3026'},
#  '5449': {'EL086ME07VTCANID-14691',
#   'EL086ME70WCFANID-14928',
#   'EL086ME83VUAANID-14715',
#   'PO186TL18SQVANID-30261'},
#  '5453': {'CO142HB45OXQANID-27652',
#   'CO142HB46OXPANID-27651',
#   'CO142HB47OXOANID-27650',
#   'PI885SP15BVKANID-37438'},
#  '5457': {'BL152EL67KCUALID-6832',
#   'OL756EL41JOKALID-6458',
#   'SA848EL05BIKALID-894',
#   'SA848EL79DPCALID-2420'},
#  '5490': {'EL086ME77AFQANID-17720',
#   'GR087ME21OEK-9577',
#   'KI593EL68ASLANID-36521',
#   'YA996ME82YXTANID-35120'},
#  '5508': {'MI453ME71BDWANID-36853',
#   'NE343TL58ZOBANID-35621',
#   'SA850EL25BFQANID-36899',
#   'WE980EL90AGBANID-36103'},
#  '5513': {'KI442EL50BXXANID-37509',
#   'NE739EL99BSEANID-37333',
#   'PO186TL93BSKANID-37339',
#   'SA127TB18FEVANID-21079'},
#  '5549': {'BA187TL29SQKANID-30253',
#   'BM137SP66PIJANID-31130',
#   'MA172OT84QMLANID-28796',
#   'NE343TL49ZOKANID-35630'},
#  '5570': {'KE239HL13ZPUANID-35667',
#   'KY149SP24PJZANID-27973',
#   'LO651EL07DGIALID-2192',
#   'MA130HL31AQAANID-36434'},
#  '5600': {'LE446HL24AUDANID-36568',
#   'MA129HL86BOVANID-37244',
#   'VI385HL02ZMJANID-35565',
#   'ZI248HL35UCQANID-31588'},
#  '5609': {'NE739EL07BGIANID-36921',
#   'PO017EL72CXZANID-38283',
#   'RI405HB94ZUJANID-35790',
#   'WA362HB66XPTANID-34202'},
#  '5646': {'KE239HL13ZPUANID-35667',
#   'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519',
#   'PI885SP15BVKANID-37438'},
#  '5651': {'AP082EL98BMNALID-1001',
#   'BU171EL77FHIANID-39907',
#   'IN255EL55UJOANID-31819',
#   'SA848EL88DOTALID-2411'},
#  '5667': {'MA129EL71VCEANID-32356',
#   'MA129HL31GBKANID-21666',
#   'PH789EL28AATANID-35956',
#   'TO241EL36URZANID-32067'},
#  '5679': {'BA187TL29SQKANID-30253',
#   'CA189EL61JZEALID-6738',
#   'CL225EL02AFPANID-36091',
#   'PR445HL28ATZANID-36564'},
#  '5688': {'BM137SP56BIHANID-37016',
#   'NE739EL02BSBANID-37330',
#   'SA848EL55JGEALID-6244',
#   'SA850EL31ERWALID-3168'},
#  '5722': {'AD429EL53ESWANID-39525',
#   'EX335TL22VPPANID-32706',
#   'HI147SP52PIXANID-31116',
#   'NE739EL78UMNANID-31896'},
#  '5723': {'EL086ME29ISSANID-23468',
#   'EL086ME80PGX-10318',
#   'GR087ME00PJZ-10398',
#   'GR087ME86PCV-10212'},
#  '4736': {'EL086ME30ISRANID-23467',
#   'EL086ME99PCI-10199',
#   'GR087ME18QGJ-10980',
#   'PE091ME91PZS-10807'},
#  '5747': {'HP467EL87AAMALID-12',
#   'NI743EL09ORIANID-27488',
#   'SA848EL64FSLANID-21433',
#   'SA850EL23EKMALID-2976'},
#  '5755': {'4M850TB06GDHANID-40528',
#   'GL346TB64XALANID-33759',
#   'PO094TB15FZCANID-40934',
#   'PO094TB24FYTANID-40680'},
#  '5764': {'BL301HL60VRZANID-32815',
#   'BL334HL75VNOANID-32653',
#   'MA129HL06GCJANID-21691',
#   'NA220HL15TVSANID-31400'},
#  '5774': {'EL086ME64JCXANID-23733',
#   'EL086ME67JCUANID-23730',
#   'PO017EL88KRJALID-7211',
#   'SA848EL94BKRANID-37080'},
#  '5781': {'NA220HL92AZFANID-36707',
#   'WA362HB01BCSANID-36823',
#   'WA362HB35ZHGANID-35410',
#   'WA362HB68XPRANID-34200'},
#  '5799': {'KO156HL26PNTANID-28107',
#   'MA129HL02PSNANID-28231',
#   'MA129HL31GBKANID-21666',
#   'WA362HB56HNVANID-41713'},
#  '5824': {'BI171EL41CRMANID-38104',
#   'HT468EL24TCDANID-30552',
#   'PO389TL59YYQANID-35176',
#   'SO888EL88TSXANID-31327'},
#  '5390': {'GR087ME69TSS-13329',
#   'WA362HB05BCOANID-36819',
#   'WA362HB13BCGANID-36811',
#   'WA362HB33ZHIANID-35412'},
#  '5833': {'CL225EL11AUQANID-36581',
#   'MA129EL71VCEANID-32356',
#   'ZI248HL33UCSANID-31590',
#   'ZI248HL34UCRANID-31589'},
#  '5871': {'GR087ME13CJYANID-19184',
#   'GR087ME22DKNANID-19875',
#   'GR087ME56IZJANID-23641',
#   'TA909EL88EPRALID-3111'},
#  '5883': {'KI593EL68ASLANID-36521',
#   'WA362HB05BCOANID-36819',
#   'WA362HB06BCNANID-36818',
#   'WA362HB14BCFANID-36810'},
#  '5884': {'GR087ME10TFP-12988',
#   'GR087ME68UAL-13530',
#   'GR087ME77RYG-12121',
#   'TR212TL05BRYANID-37328'},
#  '5909': {'PE224TB49TIWANID-30874',
#   'SA127TB00FFNANID-21097',
#   'SA127TB12FFBANID-21085',
#   'SA127TB99FFOANID-21098'},
#  '5969': {'EL086ME11TCQANID-30564',
#   'EL086ME81JCGANID-23716',
#   'EL086ME94WQRANID-15304',
#   'KE089ME54XPHANID-15944'},
#  '5962': {'HT468EL25TCCANID-30551',
#   'MO726EL84JIXALID-6315',
#   'WE133EL79VVCANID-32919',
#   'WE133EL83UIMANID-31791'},
#  '5996': {'BE463HB56BMDANID-37148',
#   'GR087ME07HKYANID-22590',
#   'GR087ME19PJG-10379',
#   'SE143HB52JLZANID-43205'},
#  '5459': {'AI440EL99IJGANID-42368',
#   'CR198TL31SUEANID-30349',
#   'HA194SP44STRANID-30335',
#   'RO461TL85BLAANID-37089'},
#  '6012': {'EL086ME05NFAANID-26492',
#   'EL086ME11NEUANID-26486',
#   'EL086ME86NFTANID-26511',
#   'EL086ME97NFIANID-26500'},
#  '5056': {'MA130HL28GBNANID-21669',
#   'MI714SP60PETANID-27837',
#   'OX378HL00ABVANID-35984',
#   'PO186TL83DQUANID-38780'},
#  '6131': {'BR337HL79VRGANID-32796',
#   'NA220HL37TFMANID-30640',
#   'NA220HL73THYANID-30709',
#   'TR942EL66EQNALID-3133'},
#  '6169': {'CL225EL91ZQQANID-35689',
#   'OG370TL32BJFANID-37039',
#   'SA395EL20ZDZANID-35320',
#   'SW459TL33BJEANID-37038'},
#  '6179': {'BU233HL39TQYANID-31269',
#   'TE440HL16AYHANID-36682',
#   'TE440HL28AXVANID-36669',
#   'WE980EL96AFVANID-36097'},
#  '6173': {'KA579EL93VUOANID-32905',
#   'PA354HL28CGLANID-37731',
#   'PA354HL34CGFANID-37725',
#   'SE861EL62DPTALID-2437'},
#  '6285': {'CA338TB48DKLANID-38608',
#   'DI453ME20FBVANID-39764',
#   'KA294HL25UWGANID-32192',
#   'PO094TB21FYWANID-40781'},
#  '6351': {'BL152EL85CRUALID-1814',
#   'CA189EL37JWGALID-6662',
#   'CA189EL61JZEALID-6738',
#   'HP467EL57JZIALID-6742'},
#  '6406': {'HP467EL57JZIALID-6742',
#   'OX378EL05YWWANID-35096',
#   'SA851EL98ATHALID-501',
#   'SO888EL89TSWANID-31326'},
#  '6339': {'LI228HL19TNWANID-31081',
#   'MA129HL94PSVANID-28239',
#   'VI385HL57YRAANID-34942',
#   'VI385HL68YQPANID-34931'},
#  '6442': {'HP467EL73TECANID-30603',
#   'NI743EL12XNZANID-34133',
#   'UN244SP45TYKANID-31470',
#   'UN244SP96XOPANID-34172'},
#  '6162': {'GO360TB19XNSANID-34120',
#   'HU242TB55TYAANID-31460',
#   'MA172OT83QMMANID-28797',
#   'MA178TB20CWDANID-38224'},
#  '6486': {'BL152EL08FQTANID-21389',
#   'BL152EL24JHJALID-6275',
#   'CA189EL38IJTALID-5661',
#   'CA189EL42IJPALID-5657'},
#  '6500': {'HP467EL57JZIALID-6742',
#   'HP467EL74JYRALID-6725',
#   'NE739EL01BSCANID-37331',
#   'NE739EL07BGIANID-36921'},
#  '6557': {'GR087ME32ODZ-9566',
#   'GR087ME37LQK-7861',
#   'GR087ME55LPS-7843',
#   'MI183ME41QZQANID-29138'},
#  '6565': {'RO834EL24BNJANID-37206',
#   'SI876EL24ZDVANID-35316',
#   'SO887EL49DXYALID-2650',
#   'WT402SP43ZSMANID-35741'},
#  '6575': {'MA129HL65XLYANID-34073',
#   'NA220HL32TFRANID-30645',
#   'NE739EL00BSDANID-37332',
#   'NE739EL01BSCANID-37331'},
#  '6585': {'EL086ME33ISOANID-23464',
#   'EL086ME98PNX-10500',
#   'SO888EL28VTFANID-32847',
#   'TR305TB50WABANID-33074'},
#  '6588': {'BL301HL50VCZANID-32378',
#   'BL301HL56VCTANID-32372',
#   'RU329SP81VNIANID-32647',
#   'VI385HL02ZMJANID-35565'},
#  '6631': {'CH134EL76PTNANID-28257',
#   'CR351EL04DPZANID-38759',
#   'CR351EL59IOQANID-42508',
#   'SI876EL04DRZALID-2495'},
#  '5700': {'BO153HB90PLHANID-28043',
#   'BO153HB91PLGANID-28042',
#   'GO487HB35FIYANID-39953',
#   'HP467EL57JZIALID-6742'},
#  '6654': {'EL086ME53IRUANID-23444',
#   'EL086ME86AURANID-18111',
#   'EL086ME90VMBANID-14508',
#   'GR087ME59SWA-12739'},
#  '6675': {'HP467EL87JUIALID-6612',
#   'KE239HL13ZPUANID-35667',
# ...
#   'LI228HL29TNMANID-31071',
#   'LU168HL48CRFANID-38096',
#   'NE739EL06BGJANID-36922'},
#  '13668': {'KI442EL59BXOANID-37500',
#   'MA130HL04VUDANID-32894',
#   'SA848EL30SQJANID-30243',
#   'VI385HL02ZMJANID-35565'},
#  '13666': {'MA130HL57XMGANID-34070',
#   'NA220HL29AXUANID-36668',
#   'NA220HL99AYYANID-36700',
#   'SA848EL54JGFALID-6245'},
#  '13676': {'CH134EL79PTKANID-28254',
#   'SA395EL19ZEAANID-35321',
#   'SH866EL22KQBALID-7177',
#   'VI385HL04ZMHANID-35563'},
#  '13678': {'GL433HL37APUANID-36428',
#   'GL433HL38APTANID-36427',
#   'GL433HL40APRANID-36425',
#   'GL433HL41APQANID-36424'},
#  '13684': {'IM400EL66ZRPANID-35718',
#   'NI743EL08ORJANID-27489',
#   'SA850EL61EMWALID-3038',
#   'WE133EL60ADJANID-36029'},
#  '13689': {'BO153HB91PLGANID-28042',
#   'BO153HB93PLEANID-28040',
#   'GL346TB62XANANID-33761',
#   'SA127TB24FEPANID-21073'},
#  '12352': {'MA129HL03VUEANID-32895',
#   'MA129HL22VTLANID-32876',
#   'MA129HL25VTIANID-32873',
#   'NO749EL29YGOANID-34670'},
#  '13765': {'MA129HL24GBRANID-34127',
#   'MO486TL59FIAANID-39923',
#   'OX378HL01BGOANID-36927',
#   'OX378HL02BGNANID-36926'},
#  '13790': {'EU364TL74XTHANID-34294',
#   'GO426HL42AHXANID-36175',
#   'RU329SP89VNAANID-32639',
#   'RU329SP94VMVANID-32634'},
#  '13817': {'CL225EL93ZQOANID-35687',
#   'CL225EL94ZQNANID-35686',
#   'TE440HL83ARWANID-36526',
#   'TE440HL89ARQANID-36488'},
#  '13823': {'CL225EL16AULANID-36576',
#   'EL086ME53PEC-10245',
#   'EL180SP44APNANID-36421',
#   'GO439HL01AREANID-36476'},
#  '13837': {'GL433HL37APUANID-36428',
#   'GL433HL40APRANID-36425',
#   'GL433HL41APQANID-36424',
#   'HO352HL06XVXANID-34374'},
#  '13838': {'MA172TL16AQPANID-36449',
#   'PI885SP88CTNANID-38157',
#   'RU329SP43IWYANID-42764',
#   'TE440HL28AXVANID-36669'},
#  '13840': {'CL199TL30SUFANID-30350',
#   'CR198TL31SUEANID-30349',
#   'EX335TL19VPSANID-32708',
#   'HO188TL39ZOUANID-35640'},
#  '13873': {'AC465SP81BPAANID-37249',
#   'AC465SP82BOZANID-37248',
#   'AS100EL28BPFALID-1071',
#   'SA395EL68ZFZANID-35375'},
#  '13883': {'SE143HB83PAAANID-27714',
#   'SE143HB88OZVANID-27709',
#   'SE143HB94OZPANID-27703',
#   'SE143HB95OZOANID-27702'},
#  '13876': {'EL086ME24LJF-7674',
#   'EL086ME49PEG-10249',
#   'EL086ME53IRUANID-23444',
#   'GR088ME64PWX-10734'},
#  '13885': {'MA129EL71VCEANID-32356',
#   'MA129HL23VTKANID-32875',
#   'MA129HL24GBRANID-21673',
#   'NA220HL16IQHANID-42591'},
#  '13926': {'EL086ME13MGS-8285',
#   'KR545HL83KLSANID-43876',
#   'MA172TL44HOHANID-41725',
#   'NE739EL54BARANID-36745'},
#  '13931': {'RM139TB38OUBANID-27559',
#   'RM139TB39OUAANID-27558',
#   'RM139TB41OTYANID-27556',
#   'RM139TB42OTXANID-27555'},
#  '13932': {'7G405SP97ENIANID-39369',
#   '7G405SP99ENGANID-39367',
#   'CH134EL76PTNANID-28257',
#   'TH256SP52UJRANID-31822'},
#  '13929': {'EL086ME02JBLANID-23695',
#   'EL086ME85VMGANID-14513',
#   'GR087ME28PFB-10270',
#   'HP467EL90AAJALID-9'},
#  '13735': {'BL301HL58VCRANID-32370',
#   'MA129HL24GBRANID-34127',
#   'WT402SP39ZSQANID-35745',
#   'WT402SP40ZSPANID-35744'},
#  '13950': {'PI885SP09BVQANID-37444',
#   'SA127TB14FEZANID-21083',
#   'SA127TB18FEVANID-21079',
#   'XT336TL70IVXANID-42737'},
#  '13999': {'MA172TL16AQPANID-36449',
#   'PI885SP07BVSANID-37446',
#   'TO241HL11ZPWANID-35669',
#   'TR212TL24BBVANID-36799'},
#  '14004': {'DE356HB48DVZANID-38918',
#   'GO360TB18XNTANID-34121',
#   'PL300TB79VBWANID-32348',
#   'SA848EL07YLGANID-34792'},
#  '14061': {'BL301HL55VCUANID-32373',
#   'BL301HL62VCNANID-32366',
#   'LA196HL84XSXANID-34284',
#   'MA129EL70VCFANID-32357'},
#  '13598': {'AP082EL19AQMANID-36446',
#   'AP082EL19AQMANID-36768',
#   'AP082EL22AQJANID-36443',
#   'AP082EL22AQJANID-36765'},
#  '14133': {'CA189EL95BSIANID-37337',
#   'HP467EL30ZPDANID-35649',
#   'NI213HL27XJOANID-34000',
#   'PH789EL03ATCALID-496'},
#  '14147': {'KE239HL13ZPUANID-35667',
#   'KI442EL50BXXANID-37509',
#   'MA172TL16AQPANID-36449',
#   'SH866EL17YWKANID-35084'},
#  '9579': {'KI442EL88BKXANID-37086',
#   'NE739EL91DUIANID-38875',
#   'OX378HL29DPAANID-38727',
#   'VA455HL14BGBANID-36914'},
#  '14168': {'BL301HL55VCUANID-32373',
#   'GA121EL10ETPANID-20787',
#   'SA848EL40XFFANID-33887',
#   'SW459TL33BJEANID-37038'},
#  '14179': {'KE239HL16ZPRANID-35664',
#   'RA140TB19AMQANID-36337',
#   'ST376HL12YDJANID-34584',
#   'TO241HL12ZPVANID-35668'},
#  '14203': {'BU233HL12TRZANID-31303',
#   'BU233HL14TRXANID-31301',
#   'KI442EL43BYEANID-37516',
#   'PO186TL18ZXHANID-35866'},
#  '14210': {'MA129HL24GBRANID-21673',
#   'PO186TL27BBSANID-36796',
#   'SA848EL39XFGANID-33888',
#   'SA851EL61GMSANID-40831'},
#  '14259': {'DR447HL31BBOANID-36780',
#   'MA129HL24GBRANID-34127',
#   'MA130HL31AQAANID-36434',
#   'VI326HL72XPNANID-34196'},
#  '14257': {'LU168HL47CRGANID-38097',
#   'OX378HL29DPAANID-38727',
#   'OX378HL93ACCANID-35991',
#   'PY258HL32UKLANID-31842'},
#  '9301': {'RA140TB02ANHANID-36354',
#   'RA140TB04ANFANID-36352',
#   'WE980EL94AFXANID-36099',
#   'WE980EL95AFWANID-36098'},
#  '14278': {'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'MO340HL89XLAANID-34038',
#   'MO340HL90XKZANID-34037'},
#  '14304': {'BU171EL75FHKANID-39909',
#   'NI743EL12XNZANID-34133',
#   'RA140TB03ANGANID-36353',
#   'SA850EL78EMFALID-3021'},
#  '14315': {'GR087ME50HFLANID-22447',
#   'GR087ME80TKP-13118',
#   'LO651EL27FFKANID-39857',
#   'SA850EL05DXQANID-38961'},
#  '14361': {'CA201SP48UJVANID-31826',
#   'CA201SP49UJUANID-31825',
#   'EL086ME17WICANID-15081',
#   'PH789EL05DKGALID-2294'},
#  '13589': {'BL368HL63DZGANID-39003',
#   'BU233HL13TRYANID-31302',
#   'KE239HL16ZPRANID-35664',
#   'MA129HL23GBSANID-21674'},
#  '13287': {'GA245HL84UATANID-31531',
#   'GA245HL85UASANID-31530',
#   'MA129HL24GBRANID-34127',
#   'MA129HL36CVNANID-38208'},
#  '14404': {'GA245HL86UARANID-31529',
#   'OX378HL29DPAANID-38727',
#   'PO186TL96HQDANID-41806',
#   'TE440HL28AXVANID-36669'},
#  '10672': {'FU348EL97VUKANID-32901',
#   'HP467EL90AAJALID-9',
#   'OG370TL91XWMANID-34389',
#   'PH789EL83AAQALID-16'},
#  '14553': {'BL334HL71VNSANID-32742',
#   'LA407HL44ZWHANID-35840',
#   'PO389TL58YYRANID-35177',
#   'PR445HL32ATVANID-36560'},
#  '14564': {'DE356HB48DVZANID-38918',
#   'GR087ME73TOS-13225',
#   'SA395EL59ZGIANID-35384',
#   'YA996ME31BFKANID-36893'},
#  '14587': {'BM137SP58PIRANID-27939',
#   'BM137SP65PIKANID-27932',
#   'ST376HL12YDJANID-34584',
#   'TA909EL49XMOANID-34083'},
#  '14604': {'AS100EL76EGLANID-39190',
#   'LA446HB47HZSANID-42118',
#   'NE739EL52BATANID-36747',
#   'SA395EL08ZELANID-35332'},
#  '14579': {'EL086ME58BHHANID-18439',
#   'KE239HL16ZPRANID-35664',
#   'NA390HB06ZARANID-35229',
#   'NA390HB16ZAHANID-35219'},
#  '14642': {'CL225EL91ZQQANID-35689',
#   'GA245HL85UASANID-31530',
#   'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519'},
#  '14646': {'EL086ME18XQRANID-15980',
#   'GR087ME29ZCSANID-16969',
#   'GR087ME31LUM-7967',
#   'GR087ME75ZAYANID-16923'},
#  '14662': {'MA130HL31AQAANID-36434',
#   'PA216SP28TBZANID-30548',
#   'SA848EL94BKRANID-37080',
#   'SA850EL93DYCANID-38973'},
#  '14669': {'IM333EL54DVTANID-38912',
#   'LG639EL02BVXANID-37457',
#   'SA850EL10DXLANID-38956',
#   'WE133EL50CUZANID-38194'},
#  '14675': {'BL301HL48VDBANID-32380',
#   'BL301HL55VCUANID-32373',
#   'BL301HL56VCTANID-32372',
#   'BL301HL58VCRANID-32370'},
#  '14708': {'GO439HL01AREANID-36476',
#   'GR087ME55RZC-12143',
#   'MA129HL23GBSANID-21674',
#   'QU369EL94AJTANID-36253'},
#  '14772': {'BL152EL91UPWANID-32012',
#   'EU364TL72XTJANID-34296',
#   'FU348EL36AIDANID-36211',
#   'LG639EL10AYNANID-36689'},
#  '14790': {'OX365TL28GNZANID-40947',
#   'PO186TL83DQUANID-38780',
#   'SW459TL33BJEANID-37038',
#   'TR212TL41ZHAANID-35402'},
#  '14809': {'NE739EL50BAVANID-36749',
#   'PU381HB67YIYANID-34732',
#   'WA362HB01BCSANID-36823',
#   'WA362HB98BCVANID-36826'},
#  '14796': {'BL152EL81CRYALID-1818',
#   'CA199EL49EHMANID-39217',
#   'GR087ME00TNR-13198',
#   'PO186TL76VRJANID-32799'},
#  '14826': {'CU302HL10VENANID-32418',
#   'CU302HL16VEHANID-32412',
#   'CU302HL62VGJANID-32466',
#   'CU302HL99VEYANID-32429'},
#  '14850': {'KI593EL68ASLANID-36521',
#   'OG370TL34BJDANID-37037',
#   'SA850EL25BFQANID-36902',
#   'WE133EL60ADJANID-36029'},
#  '14862': {'HP467EL75JYQALID-6724',
#   'KI593EL68ASLANID-36521',
#   'NE739EL99BSEANID-37333',
#   'SA848EL32CRVANID-38113'},
#  '14832': {'FU348EL23BJOANID-37048',
#   'KI593EL69ASKANID-36520',
#   'PH789EL28AATANID-35956',
#   'TE440HL16AYHANID-36682'},
#  '14148': {'CL225EL86ZQVANID-35694',
#   'RA140TB05ANEANID-36351',
#   'RM139TB53OTMANID-27544',
#   'RM139TB71OSUANID-27526'},
#  '14870': {'GR087ME88TOD-13210',
#   'MA172TL16AQPANID-36449',
#   'PY258HL21UKWANID-31906',
#   'SA850EL25BFQANID-36902'},
#  '14889': {'GR087ME18SPX-12580',
#   'GR087ME32SPJ-12566',
#   'GR087ME49THY-13049',
#   'GR087ME61TLI-13137'},
#  '14950': {'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519',
#   'NO749EL09YHIANID-34690',
#   'SI876EL03DSAALID-2496'},
#  '14951': {'AS100EL83BNCALID-1016',
#   'NI743EL61IIWALID-5638',
#   'VA956EL91ANSANID-36365',
#   'VA956EL93ANQANID-36363'},
#  '14993': {'AP082EL36BDJALID-763',
#   'KI442EL56BXRANID-37503',
#   'KI442EL66ASNANID-36523',
#   'MI364EL27DWUANID-38939'},
#  '14994': {'KE239HL16ZPRANID-35664',
#   'NE739EL77UMOANID-31897',
#   'NE739EL83BFKALID-816',
#   'PI885SP15BVKANID-37438'},
#  '14992': {'BL152EL67KCUALID-6832',
#   'SH866EL91AJWANID-36256',
#   'SH866EL93AJUANID-36254',
#   'TO939EL35TUYANID-31380'},
#  '14991': {'LA196HL69ZJUANID-35479',
#   'LI228HL26TNPANID-31074',
#   'NA220HL98TGZANID-30684',
#   'PT341HL38XMZANID-34094'},
#  '15031': {'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'NE739EL91DUIANID-38875',
#   'SA848EL71FSEANID-21426'},
#  '14997': {'BL152EL87CRSALID-1812',
#   'CA189EL32YODANID-34867',
#   'FU348EL09GBIALID-4090',
#   'KO597EL47FZWALID-4052'},
#  '15052': {'EL086ME33WTAANID-15365',
#   'EL086ME74UXHANID-14124',
#   'EL086ME75LLC-7723',
#   'PE091ME72YXFANID-16826'},
#  '15057': {'IS456EL93KDQANID-43665',
#   'LE637EL87CPSANID-38057',
#   'MO726EL42YNTANID-34857',
#   'NE739EL77UMOANID-31897'},
#  '15074': {'KI593EL68ASLANID-36521',
#   'KI593EL70ASJANID-36519',
#   'NO749EL32AZRALID-667',
#   'NO749EL33YGKANID-34666'},
#  '15091': {'CL225EL11AUQANID-36581',
#   'KE239HL16ZPRANID-35664',
#   'KI593EL69ASKANID-36520',
#   'TA909EL49XMOANID-34083'},
#  '15129': {'EL086ME34QFT-10964',
#   'EL086ME50QMV-11148',
#   'GR087ME36QBV-10862',
#   'RM139TB66OSZANID-27531'},
#  '15144': {'DR447HL26AXXANID-36672',
#   'LA196HL94VQRANID-32781',
#   'OI176TL53CUWANID-38189',
#   'PH789EL23XFWANID-33904'},
#  '15161': {'RM139TB64OTBANID-27533',
#   'RM139TB66OSZANID-27531',
#   'RM139TB69OSWANID-27528',
#   'RM139TB71OSUANID-27526'},
#  '8638': {'GR087ME17TFI-12981',
#   'GR087ME33TES-12965',
#   'GR087ME59TWY-13439',
#   'GR087ME77GHIANID-21820'},
#  '15183': {'AP082EL36CPVALID-1763',
#   'AP082EL38CPTALID-1761',
#   'AP082EL39CPSALID-1760',
#   'CA189EL64IEXALID-5535'},
#  '15207': {'AS100EL28BPFALID-1071',
#   'HP467EL57JZIALID-6742',
#   'NE739EL02BSBANID-37330',
#   'NE739EL07BGIANID-36921'},
#  '15216': {'GE362EL09EUOANID-39575',
#   'NE739EL28ETVANID-39556',
#   'NE739EL90DUJANID-38876',
#   'NE739EL91DUIANID-38875'},
#  '15228': {'BL152EL85CRUALID-1814',
#   'BL152EL91UPWANID-32012',
#   'MO726EL42YNTANID-34857',
#   'NE739EL50BAVANID-36749'},
#  '12149': {'EL086ME47WDCANID-14951',
#   'EL086ME79WRGANID-15319',
#   'NI743EL08ORJANID-27489',
#   'SA850EL73EMKALID-3026'},
#  '15256': {'HP467EL89ZBIANID-35251',
#   'LO651EL35FFCANID-39849',
#   'NO749EL00BAXALID-699',
#   'RU329SP14VMBANID-32614'},
#  '15257': {'AC016EL03YHOANID-34696',
#   'NE739EL07BGIANID-36921',
#   'SA848EL55JGEALID-6244',
#   'SA850EL23EKMALID-2976'},
#  '14738': {'GA245HL84UATANID-31531',
#   'GA245HL86UARANID-31529',
#   'KI593EL68ASLANID-36521',
#   'MD150SP14PKJANID-27983'},
#  '15287': {'MA129HL23VTKANID-32875',
#   'MA130HL29AQCANID-36436',
#   'MA130HL30AQBANID-36435',
#   'SE143HB46PBLANID-27751'},
#  '15281': {'MA129HL03VUEANID-32965',
#   'MA129HL23VTKANID-32875',
#   'MA129HL25VTIANID-32953',
#   'MA130HL30AQBANID-36435'},
#  '15319': {'KI442EL91BKUANID-37083',
#   'MO726EL78VNLANID-32650',
#   'NA220HL94AZDANID-36705',
#   'NA220HL95AZCANID-36704'},
#  '15322': {'GR087ME37UBQ-13561',
#   'GR087ME40PEP-10258',
#   'GR087ME48IRZANID-23449',
#   'GR087ME51TAE-12847'},
#  '15323': {'BL152EL12JHVALID-6287',
#   'BL152EL85CRUALID-1814',
#   'BL152EL87CRSALID-1812',
#   'BL152EL92QAPANID-28441'},
#  '15325': {'RA140TB07ANCANID-36349',
#   'RM139TB41OTYANID-27556',
#   'RM139TB79UAYANID-31536',
#   'SI138TB73OSSANID-27524'},
#  '15293': {'RM139TB29TZAANID-31486',
#   'RM139TB30TYZANID-31485',
#   'RM139TB64OTBANID-27533',
#   'RM139TB71OSUANID-27526'},
#  '13156': {'CA189EL53AVAALID-546',
#   'CL225EL93ZQOANID-35687',
#   'NE739EL01BSCANID-37331',
#   'NE739EL96CHRANID-37763'},
#  '15338': {'SE143HB46PBLANID-27751',
#   'WA362HB09BCKANID-36815',
#   'WA362HB69XPQANID-34199',
#   'WA362HB97BCWANID-36827'},
#  '15340': {'WA362HB01BCSANID-36823',
#   'WA362HB12BCHANID-36812',
#   'WA362HB69XPQANID-34199',
#   'WA362HB97BCWANID-36827'},
#  '15355': {'AC465SP80BPBANID-37250',
#   'AC465SP81BPAANID-37249',
#   'BU233HL22COJANID-37942',
#   'WA351SP66XEFANID-33857'},
#  '15376': {'GR087ME11BMYANID-18586',
#   'GR087ME52XDVANID-15646',
#   'HP467EL74JYRALID-6725',
#   'SA850EL25BFQANID-36901'},
#  '15387': {'NE739EL00BSDANID-37332',
#   'NE739EL01BSCANID-37331',
#   'NE739EL02BSBANID-37330',
#   'NE739EL06BGJANID-36922'},
#  '15421': {'GR087ME40GEXANID-21757',
#   'GR087ME93TGG-13005',
#   'NO749EL48BETANID-36876',
#   'NO749EL60JFZALID-6239'},
#  '15423': {'GO439HL01AREANID-36476',
#   'MA129HL23GBSANID-21674',
#   'MA696HL22BFTANID-36906',
#   'SA395EL63ZGEANID-35380'},
#  '15428': {'BL394HB40ATNANID-36552',
#   'WA362HB01BCSANID-36823',
#   'WA362HB13BCGANID-36811',
#   'WA362HB15BCEANID-36809'},
#  '4332': {'BL301HL44VDFANID-32384',
#   'BU233HL13TRYANID-31302',
#   'SI182HL96QPVANID-28884',
#   'ZE306HL83ZFKANID-35360'},
#  '15346': {'EL086ME30ISRANID-23467',
#   'EL086ME35QNK-11163',
#   'EL086ME98QKZ-11100',
#   'EL086ME99PCI-10199'},
#  '15402': {'EL086ME36QNJ-11162',
#   'GR087ME55THS-13043',
#   'GR087ME61TLI-13137',
#   'GR087ME66XKZANID-15832'},
#  '15444': {'LO651EL27FFKANID-39857',
#   'MD150SP13PKKANID-27984',
#   'SA395EL21ZDYANID-35319',
#   'TO241HL11ZPWANID-35669'},
#  '15490': {'WA362HB14BCFANID-36810',
#   'WA362HB37ZHEANID-35408',
#   'WA362HB66XPTANID-34202',
#   'WA362HB97BCWANID-36827'},
#  '15078': {'GL338HL56VSDANID-32819',
#   'KI593EL68ASLANID-36521',
#   'SA848EL41BMSANID-37171',
#   'SA848EL55JGEALID-6244'},
#  '15497': {'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520',
#   'KI593EL70ASJANID-36519',
#   'MA129HL24GBRANID-34127'},
#  '15522': {'KI593EL69ASKANID-36520',
#   'SA848EL32CRVANID-38113',
#   'SA848EL85FRQANID-21412',
#   'SA850EL06DXPANID-38960'},
#  '15517': {'KI593EL68ASLANID-36521',
#   'NE343TL23AEUANID-36082',
#   'PR445HL28ATZANID-36564',
#   'SA395EL63ZGEANID-35380'},
#  '15541': {'CO142HB39OXWANID-27658',
#   'WA362HB00BCTANID-36824',
#   'WA362HB14BCFANID-36810',
#   'WA362HB15BCEANID-36809'},
#  '15549': {'BL152EL92QAPANID-28441',
#   'OG370TL91XWMANID-34389',
#   'RM139TB27TZCANID-31488',
#   'RM139TB67OSYANID-27530'},
#  '15539': {'BL152EL81CRYALID-1818',
#   'DE237HB10TSBANID-31305',
#   'GR087ME37TQC-13261',
#   'WA362HB69XPQANID-34199'},
#  '15441': {'CL225EL12AUPANID-36580',
#   'EU364TL73XTIANID-34295',
#   'MO726EL42YNTANID-34857',
#   'NI743EL12AHFALID-187'},
#  '15563': {'AC016EL05YHMANID-34694',
#   'LI366TL51XUEANID-34329',
#   'MO726EL42YNTANID-34857',
#   'NE343TL74VVHANID-32924'},
#  '15611': {'CA189EL61JZEALID-6738',
#   'KE239HL13ZPUANID-35667',
#   'MA129HL23GBSANID-21674',
#   'PY258HL29UKOANID-31845'},
#  '15635': {'EU364TL73XTIANID-34295',
#   'EU364TL74XTHANID-34294',
#   'KI593EL68ASLANID-36521',
#   'KI593EL69ASKANID-36520'},
#  '15656': {'GR087ME19HZWANID-22978',
#   'GR087ME51XDWANID-15647',
#   'WA362HB18BCBANID-36806',
#   'WA362HB68XPRANID-34200'},
#  '15694': {'HP467EL75JYQALID-6724',
#   'TR212TL05BRYANID-37329',
#   'TR212TL57UBUANID-31558',
#   'YA249TL21UDEANID-31602'},
#  '15714': {'CA189EL21HNIALID-5078',
#   'GR087ME14TFL-12984',
#   'NE739EL91DUIANID-38875',
#   'SA850EL24BFRANID-36900'},
#  '15710': {'BM137SP66PIJANID-31130',
#   'DL368HL32XUXANID-34348',
#   'WA362HB07BCMANID-36817',
#   'WA362HB16BCDANID-36808'},
#  '15666': {'KI593EL68ASLANID-36521',
#   'MD150SP26DPDANID-38731',
#   'PY258HL25UKSANID-31849',
#   'PY258HL33UKKANID-31841'},
#  '15734': {'AM393SP39ZDGANID-35301',
#   'BL301HL56VCTANID-32372',
#   'NE739EL50BAVANID-36749',
#   'RU329SP89VNAANID-32639'},
#  '15737': {'PH789EL05DKGALID-2294',
#   'PO017EL72CXZANID-38283',
#   'RU329SP89CTMANID-38156',
#   'TA907EL65CUKANID-38180'},
#  '15760': {'LA407HL43ZWIANID-35841',
#   'RU329SP12VMDANID-32616',
#   'VI385HL04ZILANID-35444',
#   'VI385HL13ZICANID-35435'},
#  ...}

# %% [markdown]
# Its attributes `hold_out` and `only_new` simply reflect the respective arguments from the last call to the `split()` method and, hard to guess, `number_of_cases` yields the number of test cases.

# %%
print(data.test.hold_out)
print(data.test.only_new)
print(data.test.number_of_cases)
# Out:
# 4
# False
# 2873

# %% [markdown]
# __NOTE__: Should you wish to split the same data again, but this time with different settings, no need to read it in again. Just call `split()` again.

# %%
data.split(6, True)

print(data.train.user.count)
print(data.test.number_of_cases)
# Out:
# 904
# 1289

# %% [markdown]
# And that's it for the equally powerful and convenient `TrainTest` data structure.
